# %%
import os
import re
import pandas as pd
import hashlib  # for detecting duplicate
from tqdm.notebook import tqdm  # for progress bars

dir_name = "data/"
dir_name_csv = "data_preprocessed_csv/"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/contradiction

# %%
def replace_space_with_underscore():
    for f in os.listdir(dir_name):
        new_name = f.replace(" ", "_")
        os.rename(dir_name + f, dir_name + new_name)
    for f in os.listdir(dir_name):
        print(f)


def strip_lines(lines):
    """
    strip spaces, newlines, carriage returns from each of the lines
    """
    lines_new = []

    for line in lines:
        lines_new.append(line.strip(" \n\x0c"))

    return lines_new


def delete_blank_lines(lines):
    """
    given list of lines with \n removed, deletes those lines that are empty
    """
    lines_new = []

    for line in lines:
        if line == "":
            continue
        else:
            lines_new.append(line)

    return lines_new


def remove_time_tags(lines):
    """
    given list of lines, remove time tags at the start or end of the lines
    """
    # added requirement for 2 spaces in pat_end because it is possible a
    # time is mentioned in a question or answer
    # the ?: at the start of each group makes them non-capturing groups
    timestamp = r"(?:\d\d:\d\d(?::\d\d)?(?:[AP]M)?)"
    pat_start = "^" + timestamp + " +(.*)"
    pat_end = "(.*) {2,}" + timestamp + "$"

    lines_new = []

    for line in lines:
        match_start = re.match(pat_start, line)
        match_end = re.match(pat_end, line)

        if match_start:
            lines_new.append(match_start.groups()[0])
        elif match_end:
            lines_new.append(match_end.groups()[0])
        else:
            lines_new.append(line)

    return lines_new


def is_start_of_question(text):
    """
    determine if the text is the start of a question
    """
    pat = r"^Q[\. ] +[^ ]"

    match = re.match(pat, text)
    if match:
        return True
    else:
        return False


def is_identifying_questioner(text):
    """
    given text, determine if it is of the form:
    BY MS. SMITH:
    """
    pat = r"B[Yy][ -](M[RrSs]\. ?([A-Z][A-Za-z-]+\b ?)+|([A-Z][A-Za-z-]+\b ?)+(, ESQ))"
    match = re.search(pat, text)

    if match:
        return match.groups()[0].upper()
    else:
        return False


def find_first_question(lines):
    """
    find first question in deposition.
    returns index from lines if found
    """

    found = False
    for i, line in enumerate(lines):
        splits = split_into_num_text(line)
        if splits is None:
            continue

        _, text = splits

        if is_start_of_question(text):
            found = i
            break

    return found


def is_start_of_answer(text):
    """
    determine if the text is the start of an answer
    """
    pat = r"^A[\. ] +[^ ]"

    match = re.match(pat, text)
    if match:
        return True
    else:
        return None


def find_bad_files(dir_name):
    """
    a file is considered bad if the function find_first_question returns false
    manually checking suggests these files are not depositions
    """
    bad_files = []

    for filename in os.listdir(dir_name):
        with open(dir_name + filename, "r", encoding="windows-1252") as f:
            lines = f.readlines()

        lines = strip_lines(lines)
        lines = delete_blank_lines(lines)
        lines = remove_time_tags(lines)

        if not find_first_question(lines):
            bad_files.append(filename)

    return bad_files


def is_page_number(line):
    """
    given line from file, determine if corresponds to a page numbering
    if yes, return the page number
    if not, return 0
    """
    pat = r"0*(\d+)$"
    match = re.match(pat, line)
    if not match:
        return 0
    else:
        return int(match.groups()[0])


def find_current_page_number(lines):
    """
    given lines from file (after selecting core) determine current page number
    """
    # keep reading through lines until you find a page number
    # this will be the page number of the second page in lines
    # so subtract 1 to get page number of current page
    for line in lines:
        page_number = is_page_number(line)
        if page_number:
            return page_number - 1


def split_into_num_text(line):
    """
    given line, split it into line number and the text.
    """
    pat = r"^(\d*:)?(\d+) +(.*)$"
    match = re.match(pat, line)
    if match:
        return int(match.groups()[1]), match.groups()[2]
    else:
        return None


def is_start_of_side_chat(text):
    """
    given text, determine if it is first line of 'side chat'
    e.g. the second line in following:
    Q.  Doesn't this document imply x did y?
         MR. SMITH: Objection form.
    if yes, return the person speaking
    if not, return False
    """
    # this pattern is known to match too many things, e.g. WITNESS NAME:
    pat = r"^([A-Z]+\.?( [A-Z]+)+): +[\w\(-]"
    match = re.match(pat, text)

    if match:
        return match.groups()[0]
    else:
        return False


def is_start_of_brackets(text):
    """
    given text, determine it is start of text that is contained in brackets
    """
    pat = r"^\([^\(\)]*\)?$"
    match = re.match(pat, text)

    if match:
        return match.group()
    else:
        return False


def is_only_symbols(text):
    """
    given string, determine if it is made up of only symbols
    intention is to find things like linebreaks '- - -'
    """
    pat = "[a-zA-Z0-9]"
    match = re.search(pat, text)

    if match:
        return False
    # -- is used to indicate somebody was interrupted just before they were going to speak
    elif text == "--":
        return False
    else:
        return True


def create_dataframe_from_file(filename):
    """
    given a deposition in filename, create a dataframe
    """
    with open(dir_name + filename, "r", encoding="windows-1252") as f:
        lines = f.readlines()

    lines = strip_lines(lines)
    lines = delete_blank_lines(lines)
    lines = remove_time_tags(lines)

    return create_dataframe_from_lines(lines)


def create_dataframe_from_lines(lines):
    """
    this is the most important function in preprocessing. it loops through all the lines,
    checks what kind of line it is, and combines that line with previous lines as appropriate.
    then outputs a dataframe
    """
    # choose starting point as 5 lines above first question. this is because the questioner is almost always
    # identified within the few lines before first question
    start = find_first_question(lines) - 5
    if start is None:
        print("could not find start")
        return None

    # initialize various parameters
    ongoing_indice = 0
    current_page_number = find_current_page_number(lines[start:])
    current_line_number = 0
    ongoing_page_number = 0
    ongoing_line_number = 0
    ongoing_text = ""
    ongoing_line_type = None
    ongoing_questioner = None
    ongoing_speaker = None

    # the indice and time_added columns are included to help with debugging. they have no use for end-users
    columns = [
        "indice",
        "page_number",
        "line_number",
        "text",
        "text_type",
        "speaker",
        "time_added",
    ]
    data = []

    for i, line in enumerate(lines):
        # ignore preamble
        if i < start:
            continue

        # page_numbering is now determined by using line numbers and first page number
        # see few lines below
        if is_page_number(line):
            continue

        splits = split_into_num_text(line)
        if splits is None:
            continue

        line_number, text = splits

        if line_number < current_line_number:
            current_page_number += 1
        current_line_number = line_number

        if is_start_of_question(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "start_question",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "q"

            questioner = is_identifying_questioner(text)
            if questioner:
                ongoing_questioner = questioner
                # include something here to remove the identification of questioner from question
            ongoing_speaker = ongoing_questioner

        elif is_start_of_answer(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "start_answer",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "a"
            ongoing_speaker = "THE WITNESS"

        elif is_start_of_side_chat(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "start_chat",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "side_chat"
            ongoing_speaker = is_start_of_side_chat(text)

        elif is_identifying_questioner(text):
            ongoing_questioner = is_identifying_questioner(text)

        elif is_start_of_brackets(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "is brackets",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "brackets"
            ongoing_speaker = None

        elif is_only_symbols(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "symbols",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "symbols"
            ongoing_speaker = None

        else:
            ongoing_text += " " + text

    data.append(
        [
            ongoing_indice,
            ongoing_page_number,
            ongoing_line_number,
            ongoing_text,
            ongoing_line_type,
            ongoing_speaker,
            "end",
        ]
    )

    return pd.DataFrame(data, columns=columns)


def remove_a_q_from_text(text):
    """
    given a string, remove 'A. ' and 'Q. ' at the start of the string
    """
    pat = r"^[A|Q]\.? +(.*$)"
    match = re.match(pat, text)

    if match:
        return match.groups()[0]
    else:
        return text


def remove_a_q_from_text_in_frame(df):
    """
    given dataframe outputted from 'create_dataframe_from...',
    remove the 'A. ' and 'Q. ' at the beginning of texts of type 'a' or 'q'
    """
    df_temp = df.copy()

    aq_indices = df_temp.text_type.isin(["a", "q"])
    df_temp.loc[aq_indices, "text"] = df_temp.loc[aq_indices, "text"].map(
        remove_a_q_from_text
    )
    return df_temp


def remove_names_from_sidechat_text(df):
    """
    given dataframe outputted from 'create_dataframe_from...',
    remove the 'MR SMITH: ' or 'THE WITNESS: ' or similar
    from start of side chat
    """
    df_temp = df.copy()

    indices = df_temp.text_type == "side_chat"

    df_temp.loc[indices, "text"] = (
        df_temp.loc[indices, "text"].str.split(pat=": +").map(lambda x: x[1])
    )

    return df_temp


def create_csvs_from_directory(directory):
    """
    given a directory of text files of depositions,
    create csv files that extract data from them
    """
    for filename in tqdm(os.listdir(directory)):
        if(filename.startswith('.')):
          continue
        print(f"starting on {filename}")
        df = create_dataframe_from_file(filename)
        df = remove_a_q_from_text_in_frame(df)
        df = remove_names_from_sidechat_text(df)
        df.to_csv(dir_name_csv + filename[:-4] + ".csv")

# %%
create_csvs_from_directory(dir_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3bd9e2f23232> in <module>()
# ----> 1 create_csvs_from_directory(dir_name)
#
# NameError: name 'dir_name' is not defined

# %%
df = pd.read_csv('/content/drive/MyDrive/contradiction/data_preprocessed_csv/Dixon v. Chen 03-12-20 Chun-Ming Chen.csv')
q_a=[]
text = list (df['text'])
text_type = list (df['text_type'])
for i in range(0,len(text)):
  if(text_type[i]=='q'):
    c=i+1
    while(text_type[c]!='a' and c<len(text)):
      c=c+1
    if(c<len(text)):
      q_a.append((text[i],text[c]))

# %%
q_a
# Out:
# [("Mr. Chen, this is Andrew Rahaim. I'm the attorney for the plaintiffs. Can you hear me okay?",
#   'Yes.'),
#  ('All right.  Can you start by giving the court reporter your full name?',
#   'My name is Chun-Ming Chen.'),
#  ('And can you spell that for us?',
#   "Sure.  It's C, as in Charlie, H, as in Harry, U, as in umbrella, N, as in Nancy, hyphen, M, as in Michael, I, as in India, N, as in Nancy, G, as in George. Last name, C, as in Charlie, H, as in Harry, E, as in Edward, N, as in Nancy."),
#  ("All right.  And where do you live? What's your residence address right now?",
#   "I'm currently living in Texas."),
#  ("Okay.  We couldn't hear you.", '3900 Woodchase Drive --'),
#  ('So give us your current address.', '3900 Woodchase Drive --'),
#  ("Wait.  Say that again.  I'm sorry.",
#   '3900 Woodchase Drive, Houston, Texas.'),
#  ("What's the ZIP Code?", '77042.'),
#  ('And who do you reside there with?', 'Myself and my mother.'),
#  ('How old are you?', 'Twenty-seven.'),
#  ("And what's your date of birth, sir?", '10/31/92.'),
#  ('Are you employed?', 'No.'),
#  ('Can you tell us what your highest grade in school that you completed?',
#   "I completed a bachelor's degree."),
#  ('And where did you go to school for that, sir?', 'Georgetown University.'),
#  ('And what was the degree in?', 'Business administration.'),
#  ('Fitness administration? Business administration.  Is that correct?',
#   'The degree was in business administration.'),
#  ("Thank you. We're here to ask you some questions about an accident that happened on August 19, 2017.  If you don't understand any of the questions that I ask, don't answer it.  Ask me to repeat the question.  Okay?  Because if you answer and you didn't understand it, the record is going to presume that you did.  Okay?",
#   'Okay.'),
#  ('All right.  You were involved in an accident on Saturday, August 19, 2017.  Is that correct?',
#   'Yes.'),
#  ('The police report states that the accident happened at approximately 4:40 in the afternoon.  Does that sound correct to you?',
#   'It happened on that day in the afternoon.'),
#  ('Okay.',
#   "The exact time I don't remember. But I think the police report should have the record."),
#  ("Well, it does.  It says 1440.  So I guess that's 2:40 in the afternoon. No.  I'm sorry.  It says 1640.",
#   "I don't have -- I don't know the exact time.  But I think, according to the police report, it happened around that time."),
#  ('So 1640.  So 4:40 in the afternoon. Do you dispute that it happened at about that time?',
#   "I don't have -- I don't know the exact time.  But I think, according to the police report, it happened around that time."),
#  ('Have you read the police report?', 'Yes, I have.'),
#  ('Do you have a copy in front of you?', "No, I don't."),
#  ('All right.  So you were driving a rented car.  Is that correct?',
#   'I was driving a rental car.'),
#  ('And that was through Enterprise. Correct?',
#   "Yes.  I rented a car through -- yes.  That's correct."),
#  ('Enterprise.  Correct?', 'Yes.'),
#  ('Where did you rent the car?',
#   'I rented the car from one of the locations in New York.'),
#  ('In New York City?', "Yes.  That's correct."),
#  ('Did you rent it on the same day as the accident?',
#   'I have to double-check the receipts.'),
#  ('Do you have the receipts with you?', "No, I don't."),
#  ('What was the purpose of renting the car?',
#   'It was to move my belongings from New York to my then residence in Virginia.'),
#  ('Do you think you may have rented the car the same day or the day before?',
#   "I don't remember the exact date I rented the car.  So I have to double-check the receipts."),
#  ('Can you describe what kind of car you were driving?',
#   "Sure.  It was a black car.  A Hyundai Accent.  A hatch- -- it was -- I don't remember how many doors it had.  It was either a four-door hatchback or a two-door hatchback."),
#  ('Was anyone in the car with you?', 'No.'),
#  ('The police report states that this accident happened in the southbound lanes of Interstate 295.  Does that sound correct?',
#   'Yes.'),
#  ('Can you, in your own words, just tell us how the accident happened?',
#   "Sure.  So I was going southbound, like it was mentioned in the police report. It was in the afternoon.  I had already driven -- I started -- so I started driving from New York.  And by the time I got to the location of the accident, it was already in the afternoon.  And at the time near the accident it was stop-and-go traffic.  And by the -- and at that time it was -- I was a little bit fatigued. Because I was going down the Delaware Bridge -- so because I was already on the bridge, there was no exit until you get off the bridge.  So at the time I think I got a little bit fatigued.  And that's why I accidentally bump into the car in front of me."),
#  ('Where did the accident take place relative to the tollbooth at the Delaware Memorial Bridge?',
#   'So the accident -- so the contact was made on the bridge.  We -- after we make contact, there was -- no one was hurt from first glance.  But once we got off the bridge, both of us pulled over to the side of the road.  And that was before the tollbooth.'),
#  ('All right.  So I understand you were fatigued at the time.  Can you describe the weather conditions at the time of the accident?',
#   'At that time it was a clear day. It was sunny.  It was sunny and bright out.'),
#  ('How about the traffic conditions? Can you tell us what they were?',
#   "I'm sorry.  Can you repeat the question?"),
#  ('The traffic conditions, can you describe them just prior to the accident?',
#   'Traffic condition was very bad.  It was stop-and-go traffic.'),
#  ('So just before the collision what happened ahead of you?',
#   "So before the collision I was going roughly about ten miles an hour.  And that was because -- due to the stop-and-go traffic.  By the time I noticed the car in front of me, I slammed the brakes.  And then -- but, then, that -- apparently that was not enough.  So that's why I made contact with the car in front of me."),
#  ('Can you tell us how far away from the car in front of you your car was at the point where you slammed on your brakes?',
#   "I don't have the exact recollection or memory.  But if I had to estimate, I think it was a safe amount of distance."),
#  ('Well, can you describe for me what "a safe amount of distance" means?  I mean, how many feet is that?',
#   'The distance that you would normally see during a stop-and-go traffic.'),
#  ('Do you remember what the weather was like around the time of the accident',
#   'Lots of snow.'),
#  ('The police report seems to indicate you were in the far right lane.  Do you have any reason to dispute that?',
#   "I don't remember which lane I was in."),
#  ('All right.  Did you stop at the accident scene or continue on immediately?',
#   'So after I made contact with the car in front of me, the driver and I make -- we -- the driver made hand gestures for me to pull over to the side of the road.'),
#  ('Did you have a discussion with the driver of the other car there?',
#   'We only had a discussion after we pulled to the side of the road -- after we got off the bridge and pulled over to the side of the road.'),
#  ("Okay.  So you didn't pull over to the side of the road on the bridge itself. You got off the bridge and pulled over. Correct?",
#   "So on the bridge there is -- so I don't remember whether there were shoulder lanes on the bridge or not.  But I think -- but, to my recollection, I believe there wasn't any shoulder lanes on the bridge. So you cannot pull over.  You can only pull over after you get off the bridge."),
#  ('Did you pull over on the western side of the toll plaza?',
#   "I'm sorry.  Can you repeat your question?"),
#  ('Did you pull over after the toll plaza?',
#   'Okay.  So I pulled over after I got off the bridge and before I reached the toll plaza.'),
#  ('Okay.  So did you have a discussion with the other driver at that point?',
#   'So after we pulled over, we both got out of the car and discussed what happened.'),
#  ('Can you recall that conversation?',
#   'I apologized for making contact with the car in front of me.  And they decided to call the police.  So I complied and waited for the police to arrive.'),
#  ('How long did it take the police to arrive?', 'It took a while.'),
#  ('Did you have any more discussions with the driver of the other car after that?',
#   "I don't remember."),
#  ('How long did you have to wait for the police to arrive?',
#   'They showed up quickly.'),
#  ("You don't remember?", 'I do not remember.'),
#  ('Do you recall talking to the police officer?', 'What was your question?'),
#  ('Did you talk with the police officer?', 'Yes.'),
#  ('What did you tell the police officer?',
#   'When the police arrived on the scene, they asked for my information, to which I complied.  And then they asked me what happened.  So I told them that I was -- I had started driving from -- I was fatigued and accidentally made contact with the car in front of me.'),
#  ('Were you given a traffic summons or citation?  A ticket.',
#   'The police gave me a ticket.'),
#  ('The police report says you were given a ticket for following too closely. Does that sound accurate?',
#   'Yes.'),
#  ('And did you have a trial in the case or did you just plead guilty to it?',
#   'I do not go to trial for that case. I just paid the fine.'),
#  ("All right.  So you didn't contest the fine or the ticket.",
#   'I did not contest.  I just paid the fine.'),
#  ('Were you injured in the accident?', 'No.'),
#  ('Did you discuss anybody else getting injured -- the passenger or the driver of the car that you struck?',
#   "I'm sorry.  Can you repeat your question?"),
#  ('Did you discuss whether or not the driver of the other car or her passenger were injured?',
#   'I do not remember about that.'),
#  ('All right.  Do you recall an ambulance showing up?',
#   'I remember an ambulance showed up.'),
#  ('And did the paramedics treat anyone?',
#   "I don't recall seeing any paramedics.  I don't recall any paramedics providing treatment to anyone.")]

# %%
for i in range(len(q_a)-1):
  question1 = q_a[i][0]
  batch_of_pairs=[]
  for j in range(i+1,len(q_a)):
    question2 = q_a[j][0]
    batch_of_pairs.append([question1,question2])

# %%
# %cd fairseq-master/
# Out:
# /content/drive/My Drive/contradiction/fairseq-master

# %%
# !pip install --editable .
# %cd ..
# Out:
# Obtaining file:///content/drive/My%20Drive/contradiction/fairseq-master
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting omegaconf<2.1
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fairseq==1.0.0a0) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from fairseq==1.0.0a0) (2019.12.20)
# Requirement already satisfied: cffi in /usr/local/lib/python3.7/dist-packages (from fairseq==1.0.0a0) (1.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from fairseq==1.0.0a0) (4.41.1)
# Collecting sacrebleu>=1.4.12
#   Downloading sacrebleu-1.5.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.5 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from fairseq==1.0.0a0) (1.9.0+cu102)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from fairseq==1.0.0a0) (0.29.23)
# Collecting hydra-core<1.1
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 11.6 MB/s
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      |████████████████████████████████| 112 kB 12.5 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core<1.1->fairseq==1.0.0a0) (5.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from omegaconf<2.1->fairseq==1.0.0a0) (3.7.4.3)
# Collecting PyYAML>=5.1.*
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 13.8 MB/s
# Collecting portalocker==2.0.0
#   Downloading portalocker-2.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi->fairseq==1.0.0a0) (2.20)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->hydra-core<1.1->fairseq==1.0.0a0) (3.5.0)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141229 sha256=af324946e93fb4366cf184477616c1cfdae297c441d5d2e94c4a841f73a64990
#   Stored in directory: /root/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
# Successfully built antlr4-python3-runtime
# Installing collected packages: PyYAML, portalocker, omegaconf, antlr4-python3-runtime, sacrebleu, hydra-core, fairseq
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Running setup.py develop for fairseq
# Successfully installed PyYAML-5.4.1 antlr4-python3-runtime-4.8 fairseq-1.0.0a0 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.0.0 sacrebleu-1.5.1
# /content/drive/My Drive/contradiction

# %%
# !pip install transformers
# !pip3 install vaderSentiment
# !pip install pylcs
# Out:
# Collecting transformers
#   Downloading transformers-4.9.1-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 9.1 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.6.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 59.0 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (5.4.1)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 55.5 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub==0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.0.12 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.9.1
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 7.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Collecting pylcs
#   Downloading pylcs-0.0.6.tar.gz (3.9 kB)
# Collecting pybind11>=2.2
#   Downloading pybind11-2.7.1-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 8.0 MB/s
# Building wheels for collected packages: pylcs
#   Building wheel for pylcs (setup.py) ... error
#   ERROR: Failed building wheel for pylcs
#   Running setup.py clean for pylcs
# Failed to build pylcs
# Installing collected packages: pybind11, pylcs
#     Running setup.py install for pylcs ... done
#   DEPRECATION: pylcs was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
# Successfully installed pybind11-2.7.1 pylcs-0.0.6

# %%
# Q.    All right.  So I understand you were fatigued at the time.  Can you describe the weather conditions at the time
# of the accident?
# A.    At that time it was a clear day.
#       It was sunny.  It was sunny and bright out.

# Q.    Do you remember what the weather was like around the time of the accident
# A.    Lots of snow.


# Q.    How long did it take the police to arrive?
# A.    It took a while.
# Q.    Did you have any more discussions with the driver of the other car after that?
# A.    I don't remember.
# Q.    How long did you have to wait for the police to arrive?
# A.    They showed up quickly.

# %%
# !python main.py "Dixon v. Chen 03-12-20 Chun-Ming Chen"
# Out:
# 2021-08-05 15:38:25.974066: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Some weights of the model checkpoint at nlpaueb/legal-bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# yes
# Some weights of the model checkpoint at nlpaueb/legal-bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tcmalloc: large alloc 1425858560 bytes == 0x55c411ea6000 @  0x7ff5e7e24b6b 0x7ff5e7e44379 0x7ff58c65226e 0x7ff58c6539e2 0x7ff5d14dfc11 0x7ff5e3220e26 0x7ff5e2cb1b88 0x55c386fc7bf8 0x55c38703b6f2 0x55c387036235 0x55c386fc873a 0x55c387036b0e 0x55c387036235 0x55c386fc834b 0x55c386fc7e59 0x55c38710f25d 0x55c38707ec3b 0x55c386fc6f01 0x55c3870b8c0d 0x55c38703b0d8 0x55c387036235 0x55c386f07e2c 0x55c387038318 0x55c387035c35 0x55c386fc873a 0x55c38703793b 0x55c387035c35 0x55c386fc873a 0x55c387036b0e 0x55c387035c35 0x55c386fc873a
# tcmalloc: large alloc 1425858560 bytes == 0x55c466e74000 @  0x7ff5e7e24b6b 0x7ff5e7e44379 0x7ff58c65226e 0x7ff58c6539e2 0x7ff5d14dfc11 0x7ff5e3220e26 0x7ff5e2cb1b88 0x55c386fc7bf8 0x55c38703b6f2 0x55c387036235 0x55c386fc873a 0x55c387036b0e 0x55c387036235 0x55c386fc834b 0x55c386fc7e59 0x55c38710f25d 0x55c38707ec3b 0x55c386fc6f01 0x55c3870b8c0d 0x55c38703b0d8 0x55c387036235 0x55c386f07e2c 0x55c387038318 0x55c387035c35 0x55c386fc873a 0x55c38703793b 0x55c387035c35 0x55c386fc873a 0x55c387036b0e 0x55c387035c35 0x55c386fc873a
# ----------similar questions----------
# The police report states that the accident happened at approximately 4:40 in the afternoon.  Does that sound correct to you?
# So 1640.  So 4:40 in the afternoon. Do you dispute that it happened at about that time?
# ----------------------------
# All right.  So I understand you were fatigued at the time.  Can you describe the weather conditions at the time of the accident?
# Do you remember what the weather was like around the time of the accident
# ----------------------------
# The traffic conditions, can you describe them just prior to the accident?
# So just before the collision what happened ahead of you?
# ----------------------------
# Did you have a discussion with the driver of the other car there?
# Okay.  So did you have a discussion with the other driver at that point?
# ----------------------------
# Do you recall talking to the police officer?
# Did you talk with the police officer?
# ----------------------------
# Did you discuss anybody else getting injured -- the passenger or the driver of the car that you struck?
# Did you discuss whether or not the driver of the other car or her passenger were injured?
# ----------------------------
# -------RESULT----------------
# question-1
# All right.  So I understand you were fatigued at the time.  Can you describe the weather conditions at the time of the accident?
# Answer-1
# At that time it was a clear day. It was sunny.  It was sunny and bright out.
#
#
# question-2
# Do you remember what the weather was like around the time of the accident
# Answer-2
# Lots of snow.
# Contradiction score :  97.5800845772028 %
# ------------------------------
# question-1
# The traffic conditions, can you describe them just prior to the accident?
# Answer-1
# Traffic condition was very bad.  It was stop-and-go traffic.
#
#
# question-2
# So just before the collision what happened ahead of you?
# Answer-2
# So before the collision I was going roughly about ten miles an hour.  And that was because -- due to the stop-and-go traffic.  By the time I noticed the car in front of me, I slammed the brakes.  And then -- but, then, that -- apparently that was not enough.  So that's why I made contact with the car in front of me.
# Contradiction score :  92.63070523738861 %
# ------------------------------
# question-1
# Do you recall talking to the police officer?
# Answer-1
# What was your question?
#
#
# question-2
# Did you talk with the police officer?
# Answer-2
# Yes.
# Contradiction score :  96.75115533173084 %
# ------------------------------
# question-1
# Did you discuss anybody else getting injured -- the passenger or the driver of the car that you struck?
# Answer-1
# I'm sorry.  Can you repeat your question?
#
#
# question-2
# Did you discuss whether or not the driver of the other car or her passenger were injured?
# Answer-2
# I do not remember about that.
# Contradiction score :  99.53167201019824 %
# ------------------------------

# %%
# And my understanding from looking at the Christiana Care emergency room records were that you complained to
# them of neck and right shoulder pain.  Is that correct?
# A.    No, my feet hurt.


# What part of your body hurt the most?
# A.    My elbows and knees.

# %%
# !python main.py "Dixon v. Chen 4-28-20 Jacqueline Dixon"
# Out:
# 2021-08-05 15:58:43.538106: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Some weights of the model checkpoint at nlpaueb/legal-bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# yes
# Some weights of the model checkpoint at nlpaueb/legal-bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tcmalloc: large alloc 1425858560 bytes == 0x5619eb25a000 @  0x7fdc41b0bb6b 0x7fdc41b2b379 0x7fdbe633926e 0x7fdbe633a9e2 0x7fdc2b1c6c11 0x7fdc3cf07e26 0x7fdc3c998b88 0x561960607bf8 0x56196067b6f2 0x561960676235 0x56196060873a 0x561960676b0e 0x561960676235 0x56196060834b 0x561960607e59 0x56196074f25d 0x5619606bec3b 0x561960606f01 0x5619606f8c0d 0x56196067b0d8 0x561960676235 0x561960547e2c 0x561960678318 0x561960675c35 0x56196060873a 0x56196067793b 0x561960675c35 0x56196060873a 0x561960676b0e 0x561960675c35 0x56196060873a
# tcmalloc: large alloc 1425858560 bytes == 0x561a40228000 @  0x7fdc41b0bb6b 0x7fdc41b2b379 0x7fdbe633926e 0x7fdbe633a9e2 0x7fdc2b1c6c11 0x7fdc3cf07e26 0x7fdc3c998b88 0x561960607bf8 0x56196067b6f2 0x561960676235 0x56196060873a 0x561960676b0e 0x561960676235 0x56196060834b 0x561960607e59 0x56196074f25d 0x5619606bec3b 0x561960606f01 0x5619606f8c0d 0x56196067b0d8 0x561960676235 0x561960547e2c 0x561960678318 0x561960675c35 0x56196060873a 0x56196067793b 0x561960675c35 0x56196060873a 0x561960676b0e 0x561960675c35 0x56196060873a
# ----------similar questions----------
# And your daughter Siddiq Moore was the passenger.  Is that correct?
# And your daughter Siddiq Moore was in the car with you?
# ----------------------------
# And did your daughter Siddiq also travel with you in your car from the emergency room to your daughter's house in Maryland?
# And your daughter Siddiq Moore was in the car with you?
# ----------------------------
# And the date that you went and got your injections with Dr. Patel was the date that she got her injections?
# And you went to see Dr. Patel for some injections.  Is that correct?
# ----------------------------
# Can you tell me as you sit here today do you have complaints that you associate with the automobile accident of August 19, 2017?
# I'll reask it again, yes. Can you tell me do you have complaints from your physical reaction of your body, is your body giving you problems that you believe were caused by the first accident in August of 2017?
# ----------------------------
# Okay.  Did anyone ever suggest to you that the findings on your cervical MRI and the findings on your daughter's cervical MRI looked to be very consistent or similar?
# So as far as you know, none of the treating physicians that you ever were seen by ever suggested to you that the results of your MRI, your cervical MRI was very similar to the results of your daughter's cervical MRI?
# ----------------------------
# -------RESULT----------------
# question-1
# And your daughter Siddiq Moore was the passenger.  Is that correct?
# Answer-1
# Correct.
#
#
# question-2
# And your daughter Siddiq Moore was in the car with you?
# Answer-2
# Siddiq was in the car.
# Contradiction score :  99.33801563456655 %
# ------------------------------
# question-1
# And did your daughter Siddiq also travel with you in your car from the emergency room to your daughter's house in Maryland?
# Answer-1
# Yes, she did.
#
#
# question-2
# And your daughter Siddiq Moore was in the car with you?
# Answer-2
# Siddiq was in the car.
# Contradiction score :  99.63668382260948 %
# ------------------------------
# question-1
# Can you tell me as you sit here today do you have complaints that you associate with the automobile accident of August 19, 2017?
# Answer-1
# Can you repeat that?
#
#
# question-2
# I'll reask it again, yes. Can you tell me do you have complaints from your physical reaction of your body, is your body giving you problems that you believe were caused by the first accident in August of 2017?
# Answer-2
# I want to say that off and on I still have pain in my neck.  Do I deal with it?  Yes.  Do I take anything?  Yes.
# Contradiction score :  99.6809660224244 %
# ------------------------------
# question-1
# Okay.  Did anyone ever suggest to you that the findings on your cervical MRI and the findings on your daughter's cervical MRI looked to be very consistent or similar?
# Answer-1
# No one talked to me about my daughter's test.
#
#
# question-2
# So as far as you know, none of the treating physicians that you ever were seen by ever suggested to you that the results of your MRI, your cervical MRI was very similar to the results of your daughter's cervical MRI?
# Answer-2
# No.
# Contradiction score :  99.30182038806379 %
# ------------------------------

# %%
# Q.  Do you see your blue truck in that photo?
# A.  As far as I can tell, that's my truck on the right.

# Q.  Okay.  Do you know who the person in the hard hat is next to that vehicle?
# A.  No.  I don't recall who it is.

# Q.  Is that your police vehicle on the right there?
# A.  No, that truck belongs to my supervisor.

# %%
# !python main.py "Kelley v. DeLucca Fence Company - 3-13-20 - Robert Peabody - FINAL.d20200323-u204511"
# Out:
# 2021-08-05 16:30:45.426831: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Some weights of the model checkpoint at nlpaueb/legal-bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# yes
# Some weights of the model checkpoint at nlpaueb/legal-bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tcmalloc: large alloc 1425858560 bytes == 0x55d583890000 @  0x7f7fc7f6ab6b 0x7f7fc7f8a379 0x7f7f6c79826e 0x7f7f6c7999e2 0x7f7fb1625c11 0x7f7fc3366e26 0x7f7fc2df7b88 0x55d4fb840bf8 0x55d4fb8b46f2 0x55d4fb8af235 0x55d4fb84173a 0x55d4fb8afb0e 0x55d4fb8af235 0x55d4fb84134b 0x55d4fb840e59 0x55d4fb98825d 0x55d4fb8f7c3b 0x55d4fb83ff01 0x55d4fb931c0d 0x55d4fb8b40d8 0x55d4fb8af235 0x55d4fb780e2c 0x55d4fb8b1318 0x55d4fb8aec35 0x55d4fb84173a 0x55d4fb8b093b 0x55d4fb8aec35 0x55d4fb84173a 0x55d4fb8afb0e 0x55d4fb8aec35 0x55d4fb84173a
# tcmalloc: large alloc 1425858560 bytes == 0x55d5d885e000 @  0x7f7fc7f6ab6b 0x7f7fc7f8a379 0x7f7f6c79826e 0x7f7f6c7999e2 0x7f7fb1625c11 0x7f7fc3366e26 0x7f7fc2df7b88 0x55d4fb840bf8 0x55d4fb8b46f2 0x55d4fb8af235 0x55d4fb84173a 0x55d4fb8afb0e 0x55d4fb8af235 0x55d4fb84134b 0x55d4fb840e59 0x55d4fb98825d 0x55d4fb8f7c3b 0x55d4fb83ff01 0x55d4fb931c0d 0x55d4fb8b40d8 0x55d4fb8af235 0x55d4fb780e2c 0x55d4fb8b1318 0x55d4fb8aec35 0x55d4fb84173a 0x55d4fb8b093b 0x55d4fb8aec35 0x55d4fb84173a 0x55d4fb8afb0e 0x55d4fb8aec35 0x55d4fb84173a
# ----------similar questions----------
# All right.  And have you ever been deposed before?
# Have you ever been deposed before?
# ----------------------------
# And what is your position there?
# And what is just a brief description of your duties there?
# ----------------------------
# Did anyone else arrive on the scene?
# Do you know if anyone else did?
# ----------------------------
# Did you speak to him at all other than that?
# When you were there, did you speak to anyone besides Mr. Kelley?
# ----------------------------
# Okay.  And are these the two dumpsters you were talking about?
# Okay.  And those are the same two dumpsters we were talking about before?
# ----------------------------
# Okay.  And are these the two dumpsters you were talking about?
# I'll have you take a look at this. Are these the two dumpsters that you recall seeing on the date of the incident?
# ----------------------------
# And so the dumpster to the right with the Crescio label, is that where Mr. Kelley was found?
# Is the dumpster on the left the one Mr. Kelley was found in?
# ----------------------------
# And so the dumpster to the right with the Crescio label, is that where Mr. Kelley was found?
# Looking at the top left photo in the incident report holding it horizontally, is that the dumpster where Mr. Kelley was found?
# ----------------------------
# By your recollection, he would have dropped off that empty dumpster?
# And so that would be the dumpster he told you he dropped off, correct?
# ----------------------------
# When you were there, did you speak to anyone besides Mr. Kelley?
# Okay.  Did you speak with anyone else at the incident scene?
# ----------------------------
# Is this the dumpster that you recall seeing Mr. Kelley in?
# And the dumpster to the left is the one you saw Mr. Kelley in?
# ----------------------------
# And the dumpster to the left is the one you saw Mr. Kelley in?
# Is the dumpster on the left the one Mr. Kelley was found in?
# ----------------------------
# Is the dumpster on the left the one Mr. Kelley was found in?
# Looking at the top left photo in the incident report holding it horizontally, is that the dumpster where Mr. Kelley was found?
# ----------------------------
# Looking at the top left photo in the incident report holding it horizontally, is that the dumpster where Mr. Kelley was found?
# And one photo to the right, so the top middle photo, does that show the dumpster he was found?
# ----------------------------
# Okay.  Do you remember any other witnesses to the incident?
# Okay.  Did you speak with anyone else at the incident scene?
# ----------------------------
# -------RESULT----------------
# question-1
# All right.  And have you ever been deposed before?
# Answer-1
# What?
#
#
# question-2
# Have you ever been deposed before?
# Answer-2
# No.
# Contradiction score :  95.41796334087849 %
# ------------------------------
# question-1
# And what is your position there?
# Answer-1
# Police officer.
#
#
# question-2
# And what is just a brief description of your duties there?
# Answer-2
# To protect and serve the community and patrol the areas.
# Contradiction score :  90.2532234787941 %
# ------------------------------
# question-1
# Did anyone else arrive on the scene?
# Answer-1
# Methuen Fire.
#
#
# question-2
# Do you know if anyone else did?
# Answer-2
# Not that I know of.  She did.  She said she viewed it and saw it.
# Contradiction score :  98.68083009496331 %
# ------------------------------
# question-1
# When you were there, did you speak to anyone besides Mr. Kelley?
# Answer-1
# Yes.  I spoke with several people.
#
#
# question-2
# Okay.  Did you speak with anyone else at the incident scene?
# Answer-2
# Just my supervisor.  Other than that...
# Contradiction score :  91.16851761937141 %
# ------------------------------
# question-1
# Looking at the top left photo in the incident report holding it horizontally, is that the dumpster where Mr. Kelley was found?
# Answer-1
# Yes.
#
#
# question-2
# And one photo to the right, so the top middle photo, does that show the dumpster he was found?
# Answer-2
# I'm making sure this is the one you're talking about.
# Contradiction score :  99.31831900030375 %
# ------------------------------
# question-1
# Okay.  Do you remember any other witnesses to the incident?
# Answer-1
# There was another male party, Jimmy. I can't even say his name but.  I can't even say it.  Down at the bottom.
#
#
# question-2
# Okay.  Did you speak with anyone else at the incident scene?
# Answer-2
# Just my supervisor.  Other than that...
# Contradiction score :  99.51742049306631 %
# ------------------------------
