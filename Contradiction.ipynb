# %%
import os
import re
import pandas as pd
import hashlib  # for detecting duplicate
from tqdm.notebook import tqdm  # for progress bars

dir_name = "/content/data/"
dir_name_csv = "/content/data_preprocessed_csv/"

# %%
def replace_space_with_underscore():
    for f in os.listdir(dir_name):
        new_name = f.replace(" ", "_")
        os.rename(dir_name + f, dir_name + new_name)
    for f in os.listdir(dir_name):
        print(f)


def strip_lines(lines):
    """
    strip spaces, newlines, carriage returns from each of the lines
    """
    lines_new = []

    for line in lines:
        lines_new.append(line.strip(" \n\x0c"))

    return lines_new


def delete_blank_lines(lines):
    """
    given list of lines with \n removed, deletes those lines that are empty
    """
    lines_new = []

    for line in lines:
        if line == "":
            continue
        else:
            lines_new.append(line)

    return lines_new


def remove_time_tags(lines):
    """
    given list of lines, remove time tags at the start or end of the lines
    """
    # added requirement for 2 spaces in pat_end because it is possible a
    # time is mentioned in a question or answer
    # the ?: at the start of each group makes them non-capturing groups
    timestamp = r"(?:\d\d:\d\d(?::\d\d)?(?:[AP]M)?)"
    pat_start = "^" + timestamp + " +(.*)"
    pat_end = "(.*) {2,}" + timestamp + "$"

    lines_new = []

    for line in lines:
        match_start = re.match(pat_start, line)
        match_end = re.match(pat_end, line)

        if match_start:
            lines_new.append(match_start.groups()[0])
        elif match_end:
            lines_new.append(match_end.groups()[0])
        else:
            lines_new.append(line)

    return lines_new


def is_start_of_question(text):
    """
    determine if the text is the start of a question
    """
    pat = r"^Q[\. ] +[^ ]"

    match = re.match(pat, text)
    if match:
        return True
    else:
        return False


def is_identifying_questioner(text):
    """
    given text, determine if it is of the form:
    BY MS. SMITH:
    """
    pat = r"B[Yy][ -](M[RrSs]\. ?([A-Z][A-Za-z-]+\b ?)+|([A-Z][A-Za-z-]+\b ?)+(, ESQ))"
    match = re.search(pat, text)

    if match:
        return match.groups()[0].upper()
    else:
        return False


def find_first_question(lines):
    """
    find first question in deposition.
    returns index from lines if found
    """

    found = False
    for i, line in enumerate(lines):
        splits = split_into_num_text(line)
        if splits is None:
            continue

        _, text = splits

        if is_start_of_question(text):
            found = i
            break

    return found


def is_start_of_answer(text):
    """
    determine if the text is the start of an answer
    """
    pat = r"^A[\. ] +[^ ]"

    match = re.match(pat, text)
    if match:
        return True
    else:
        return None


def find_bad_files(dir_name):
    """
    a file is considered bad if the function find_first_question returns false
    manually checking suggests these files are not depositions
    """
    bad_files = []

    for filename in os.listdir(dir_name):
        with open(dir_name + filename, "r", encoding="windows-1252") as f:
            lines = f.readlines()

        lines = strip_lines(lines)
        lines = delete_blank_lines(lines)
        lines = remove_time_tags(lines)

        if not find_first_question(lines):
            bad_files.append(filename)

    return bad_files


def is_page_number(line):
    """
    given line from file, determine if corresponds to a page numbering
    if yes, return the page number
    if not, return 0
    """
    pat = r"0*(\d+)$"
    match = re.match(pat, line)
    if not match:
        return 0
    else:
        return int(match.groups()[0])


def find_current_page_number(lines):
    """
    given lines from file (after selecting core) determine current page number
    """
    # keep reading through lines until you find a page number
    # this will be the page number of the second page in lines
    # so subtract 1 to get page number of current page
    for line in lines:
        page_number = is_page_number(line)
        if page_number:
            return page_number - 1


def split_into_num_text(line):
    """
    given line, split it into line number and the text.
    """
    pat = r"^(\d*:)?(\d+) +(.*)$"
    match = re.match(pat, line)
    if match:
        return int(match.groups()[1]), match.groups()[2]
    else:
        return None


def is_start_of_side_chat(text):
    """
    given text, determine if it is first line of 'side chat'
    e.g. the second line in following:
    Q.  Doesn't this document imply x did y?
         MR. SMITH: Objection form.
    if yes, return the person speaking
    if not, return False
    """
    # this pattern is known to match too many things, e.g. WITNESS NAME:
    pat = r"^([A-Z]+\.?( [A-Z]+)+): +[\w\(-]"
    match = re.match(pat, text)

    if match:
        return match.groups()[0]
    else:
        return False


def is_start_of_brackets(text):
    """
    given text, determine it is start of text that is contained in brackets
    """
    pat = r"^\([^\(\)]*\)?$"
    match = re.match(pat, text)

    if match:
        return match.group()
    else:
        return False


def is_only_symbols(text):
    """
    given string, determine if it is made up of only symbols
    intention is to find things like linebreaks '- - -'
    """
    pat = "[a-zA-Z0-9]"
    match = re.search(pat, text)

    if match:
        return False
    # -- is used to indicate somebody was interrupted just before they were going to speak
    elif text == "--":
        return False
    else:
        return True


def create_dataframe_from_file(filename):
    """
    given a deposition in filename, create a dataframe
    """
    with open(dir_name + filename, "r", encoding="windows-1252") as f:
        lines = f.readlines()

    lines = strip_lines(lines)
    lines = delete_blank_lines(lines)
    lines = remove_time_tags(lines)

    return create_dataframe_from_lines(lines)


def create_dataframe_from_lines(lines):
    """
    this is the most important function in preprocessing. it loops through all the lines,
    checks what kind of line it is, and combines that line with previous lines as appropriate.
    then outputs a dataframe
    """
    # choose starting point as 5 lines above first question. this is because the questioner is almost always
    # identified within the few lines before first question
    start = find_first_question(lines) - 5
    if start is None:
        print("could not find start")
        return None

    # initialize various parameters
    ongoing_indice = 0
    current_page_number = find_current_page_number(lines[start:])
    current_line_number = 0
    ongoing_page_number = 0
    ongoing_line_number = 0
    ongoing_text = ""
    ongoing_line_type = None
    ongoing_questioner = None
    ongoing_speaker = None

    # the indice and time_added columns are included to help with debugging. they have no use for end-users
    columns = [
        "indice",
        "page_number",
        "line_number",
        "text",
        "text_type",
        "speaker",
        "time_added",
    ]
    data = []

    for i, line in enumerate(lines):
        # ignore preamble
        if i < start:
            continue

        # page_numbering is now determined by using line numbers and first page number
        # see few lines below
        if is_page_number(line):
            continue

        splits = split_into_num_text(line)
        if splits is None:
            continue

        line_number, text = splits

        if line_number < current_line_number:
            current_page_number += 1
        current_line_number = line_number

        if is_start_of_question(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "start_question",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "q"

            questioner = is_identifying_questioner(text)
            if questioner:
                ongoing_questioner = questioner
                # include something here to remove the identification of questioner from question
            ongoing_speaker = ongoing_questioner

        elif is_start_of_answer(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "start_answer",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "a"
            ongoing_speaker = "THE WITNESS"

        elif is_start_of_side_chat(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "start_chat",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "side_chat"
            ongoing_speaker = is_start_of_side_chat(text)

        elif is_identifying_questioner(text):
            ongoing_questioner = is_identifying_questioner(text)

        elif is_start_of_brackets(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "is brackets",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "brackets"
            ongoing_speaker = None

        elif is_only_symbols(text):
            data.append(
                [
                    ongoing_indice,
                    ongoing_page_number,
                    ongoing_line_number,
                    ongoing_text,
                    ongoing_line_type,
                    ongoing_speaker,
                    "symbols",
                ]
            )

            ongoing_indice = i
            ongoing_page_number = current_page_number
            ongoing_line_number = current_line_number
            ongoing_text = text
            ongoing_line_type = "symbols"
            ongoing_speaker = None

        else:
            ongoing_text += " " + text

    data.append(
        [
            ongoing_indice,
            ongoing_page_number,
            ongoing_line_number,
            ongoing_text,
            ongoing_line_type,
            ongoing_speaker,
            "end",
        ]
    )

    return pd.DataFrame(data, columns=columns)


def remove_a_q_from_text(text):
    """
    given a string, remove 'A. ' and 'Q. ' at the start of the string
    """
    pat = r"^[A|Q]\.? +(.*$)"
    match = re.match(pat, text)

    if match:
        return match.groups()[0]
    else:
        return text


def remove_a_q_from_text_in_frame(df):
    """
    given dataframe outputted from 'create_dataframe_from...',
    remove the 'A. ' and 'Q. ' at the beginning of texts of type 'a' or 'q'
    """
    df_temp = df.copy()

    aq_indices = df_temp.text_type.isin(["a", "q"])
    df_temp.loc[aq_indices, "text"] = df_temp.loc[aq_indices, "text"].map(
        remove_a_q_from_text
    )
    return df_temp


def remove_names_from_sidechat_text(df):
    """
    given dataframe outputted from 'create_dataframe_from...',
    remove the 'MR SMITH: ' or 'THE WITNESS: ' or similar
    from start of side chat
    """
    df_temp = df.copy()

    indices = df_temp.text_type == "side_chat"

    df_temp.loc[indices, "text"] = (
        df_temp.loc[indices, "text"].str.split(pat=": +").map(lambda x: x[1])
    )

    return df_temp


def create_csvs_from_directory(directory):
    """
    given a directory of text files of depositions,
    create csv files that extract data from them
    """
    for filename in tqdm(os.listdir(directory)):
        print(f"starting on {filename}")
        df = create_dataframe_from_file(filename)
        df = remove_a_q_from_text_in_frame(df)
        df = remove_names_from_sidechat_text(df)
        df.to_csv(dir_name_csv + filename[:-4] + ".csv")

# %%
create_csvs_from_directory(dir_name)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# starting on Bogel v. Jolly Trolley 02-11-20 Dean DiPietro - Inconsistencies.txt

# %%
df = pd.read_csv('/content/data_preprocessed_csv/Bogel v. Jolly Trolley 02-11-20 Dean DiPietro - Inconsistencies.csv')
q_a=[]
text = list (df['text'])
text_type = list (df['text_type'])
for i in range(0,len(text)):
  if(text_type[i]=='q'):
    c=i+1
    while(text_type[c]!='a' and c<len(text)):
      c=c+1
    if(c<len(text)):
      q_a.append((text[i],text[c]))

# %%
q_a
# Out:
# [('Good afternoon, Mr. DiPietro.', 'Hi.'),
#  ("My name is Sarah Cole.  Thank you for being here for your deposition today. You were present for your wife Cecilia -- I'm sorry. You were present for your wife's deposition, correct?",
#   'Yes.'),
#  ('And you also heard the instructions that I gave to her prior or as we started the deposition?',
#   'Yes.'),
#  ("Okay.  Just in case, I'm going to go through them just briefly for you because it's been several hours since we went through them.",
#   'Sure.'),
#  ("We have a court reporter here with us today and he's going to be writing down everything that's being stated in this room.  So any question I give, any response you provide, any objections that are made, everything is going to be encapsulated for all time in a book and someone might need to go back and read that transcript.  To make that process easier for that person, I want to make sure that the transcript is as clear as possible. For that to happen, I'm going to ask us to take turns speaking.  Wait for me to give my full question before you give a response. I'm also going to ask you to give your responses in the form of words as opposed to saying uh-huh, uh-uh or shaking your head. Also, if at any time you don't understand a question being posed to you, let me know.  That way I can fix it in some way or do whatever I can to make it more clear, whether it be restate it, rephrase it or change it in any way. If you give me an answer to a question without first telling me you didn't understand it, I'm going to believe that you understood the question and that the response you're giving is to that question. Okay?",
#   'Okay.'),
#  ("All right.  If you need a break at any time, let me know.  As you've probably noticed, I need breaks on occasion.  I'm more than willing to take breaks at any time.",
#   'Okay.  Thank you.'),
#  ("Let's get started with your full legal name, please.",
#   'Dean Anthony DiPietro.'),
#  ('What is your date of birth?', "September 9, '82."),
#  ("What's your current address?", '2815 Evarts Street, D.C.'),
#  ('You live there with your wife Cecilia?', "That's right."),
#  ('Does she go by Ceci or Cecilia?', 'A little bit of both.'),
#  ("I've heard people call her both.", 'Ceci is a little easier.'),
#  ('Yeah.  Okay. You have lived there since June of 2016?', "That's right."),
#  ('And you agree with the brief summary that she provided regarding a description of your home?',
#   'Absolutely.'),
#  ('Are you currently employed?', 'Yes.'),
#  ('Where do you work?',
#   'I work for the U.S. Green Building Council in Washington, D.C.'),
#  ('What is that?',
#   "You may have seen a plaque sometimes when you go into a big office building that said LEED on it, L-E-E-D.  So we're an environmental non-profit and we do an assessment of buildings and office spaces for environmental performance and we issue a rating to those buildings."),
#  ('Are you a government agency?', "No.  It's a 501(c)(3)."),
#  ('Okay.  What is your title there currently?', 'Director of operations.'),
#  ('Give me a briefly summary as to your general responsibilities and tasks as the director of operations.',
#   'Sure.  I oversee business operations for the certification and credentialing functions of the company.  So we issue plaques to buildings and certificates to people based on their knowledge of green building and everything that goes into the general business planning for that, so technology planning, budgeting, resource management, those sorts of things.'),
#  ('How long have you held the position of director of operations?',
#   "I mean I've been doing this sort of work for a long time.  I think I got the director title in early 2016, but I would have to check the records to be sure."),
#  ('Definitely before October 1st of 2016?', 'Yes.'),
#  ("Who do you report to?  What's the title, not necessarily the name, but do you report to somebody else?",
#   'The senior vice president of certification and credentialing.'),
#  ('Who is your boss?', 'The Vice President of Engineering.'),
#  ('Do you report to work at an office?', 'Yes.'),
#  ('Do you report to work at an office every day?', 'Yes.'),
#  ('And is that office somewhere off site from your home?', 'Yes.  Yeah.'),
#  ('What are your general work hours?',
#   'About the same as Ceci, so maybe 9:30 to 6:00 Monday through Friday.'),
#  ('And that would be in D.C.?', 'In D.C., yeah.  21st and L.'),
#  ('Give me a brief summary of your educational background.',
#   "Sure.  So college, undergrad at St. Mary's College, I graduated in 2005, and then grad school at University of Maryland, got my M.B.A. in 2010.  And that was a two-year part-time program."),
#  ('Is that in College Park?',
#   "Well, they actually have three campuses.  There's one in College Park, one in downtown D.C. and one in like Shady Grove, but I only really took classes at the downtown D.C. location."),
#  ('Oh, okay.  So they have a downtown D.C. location?',
#   "It's just for the business school in the Reagan Center at 14th and E.  They have like the whole basement there is they have four classrooms and a lecture hall for the business school."),
#  ("That's a two-year program you said?",
#   "That's correct.  You don't have to do it in two years.  You don't have to get the credits.  You can stretch it out longer if you need to, but normally you can get it done in two years because it's a part-time program in the evenings."),
#  ('What position did you hold immediately prior to -- well, let me strike that. When you began working in January of 2016, were you working as director of operations?',
#   'When I began working in January of 2016?'),
#  ('Let me back up. For the employer that you currently have, did you start working there in January or early 2016?',
#   'No.  And perhaps I could just give you a quick summary of my work history.'),
#  ('Yes.', 'Yes. I was hired at the U.S. Green Building Council in 2006.'),
#  ('Got it.  So you worked your way up to director of operations which is a title you presumed in early 2016?',
#   "That's correct."),
#  ('And since October of 2016, minus any time that you may have missed from work as a result of this accident, have you generally been working at your office from around until 9:30 until 6:00 p.m. Monday through Friday?',
#   'Yeah.  Absolutely.'),
#  ("So that's typical?",
#   "Right.  Similar to Cecilia, if there's a snow day or something it's okay to telework or if there's a plumber coming to the house or something like that, but there's no regular schedule of anything other than going into the office every day."),
#  ('Did you have a primary care physician before October 1st, 2016?',
#   "Not really.  I had been going regularly to the Washington Medical Group. And I know you've got like ten providers that all sound exactly the same here. But my company changed insurance plans in the summer of 2016 and so I had to stop seeing that office generally and so I was sort of in limbo there for a while."),
#  ('So you had to stop seeing a general care or a family doctor that was associated with the Washington Medical Group prior to October 1st, 2016 because your employer switched carriers or insurance?',
#   "That's right.  And honestly it was in August, so stop seeing I would put in quotes."),
#  ("Okay.  All right.  What was your doctor's name at Washington Medical Group?",
#   "It's sort of like a rotating shop. You call in and make an appointment, I'm sick, I got whatever and you talk to somebody who's working there. I saw Dr. Stephen Macedo a fair amount there, but they also have a rotating -- sorry.  Is it RN or PA?  One of those two.  I can't remember.  That you see when you go in with a cold or something like that."),
#  ('Who is the person you report to?', 'The Director of Marketing'),
#  ('Prior to October 1st, 2016 had you ever been involved in any other motor vehicle accidents?',
#   "Just one really minor accident. And I'm not really sure on the dates.  I want to guess it was 2006-ish, but I'm not really sure."),
#  ('Were you injured as a result of that 2006-ish accident?', 'No.'),
#  ('How about since October 1st, 2016, have you been involved in any additional accidents?',
#   'No.'),
#  ('Have you been hospitalized for any reason prior to October 1st, 2016?',
#   'Yeah.  So I had my tonsils out and wisdom teeth out when I was younger.  And in I want to say 2009 I had a surgery on my wrist.  I had a puncture into this wrist here (indicating) and I had to get a nerve repaired.'),
#  ('That was your right wrist?',
#   'Yeah.  That was my right wrist with the sweet scar.'),
#  ('Was that related to some kind of injury or incident that occurred to you?',
#   'It was.'),
#  ('What did you do?',
#   "It's kind of a fun story.  You'll all get a good laugh here. I was taking a nap on the couch and I kicked the lamp over in the process here.  And then I was very frustrated because it was one of Ceci's favorite lamps. I cleaned up all of the broken glass and was left with the piece that the lamp shade connects to.  And I was a little lazy.  The trash can was more full than -- you know, it was sort of full.  And I was trying to get this piece of metal to go into the trash can and I was trying to bend it.  And it was brittle and it snapped and it went directly into my wrist. So completely self-imposed. There were many different steps I could have taken to not have that problem."),
#  ('Okay.',
#   "Maybe it's worth mentioning I had that surgery done at the National Hand Center, I think it's called, in Baltimore, which is where we ended up going for Ceci's finger.  That was the connection."),
#  ('Got it. Had you ever seen any mental health providers prior to October 1st, 2016?',
#   "I've been trying to think about this.  I think the answer is no.  My parents got divorced when I was 11 and I think my brother and I went to like two counseling sessions, but it's the only thing that I can recall."),
#  ('Have you ever been on any medication for any mental health concerns prior to October 1st, 2016?',
#   "I take Adderall for ADD.  I'm not sure if that was mental behavioral or how you classify that."),
#  ('Okay.  Who prescribes that?',
#   "Well, it had been Dr. Stephen Macedo.  And I actually have paid out of pocket to get it renewed just because I haven't transferred over to another doctor, but just recently I switched over to I found a new primary care doctor so I will be switching to him."),
#  ('And was the Adderall helping with any particular diagnosis that you had received in the past?',
#   'Outside of the ADD?'),
#  ('Yes. You have ADD?', "Yes.  That's what it was for."),
#  ('Who has diagnosed you with ADD?',
#   "That's Dr. Stephen Macedo from the Washington Medical Group."),
#  ('When were you first diagnosed with that?', "'09 or 2010, in there."),
#  ('Somewhere around 2009-2010?', 'Yeah.'),
#  ('Remind me.  Which year were you and your wife married?', '2010.'),
#  ('Had you two traveled fairly extensively before October 1st, 2016?',
#   'Yeah.  One or two trips per year and often interesting ones I like to think.'),
#  ('Where did you go for your honeymoon, if anywhere?',
#   'We went to Mexico.  We went to Oaxaca, a lovely town.'),
#  ('Were you on any medication on a routine basis leading up to October 1st, 2016?',
#   'Just the Adderall.'),
#  ("Let's talk about the injuries you believe you sustained in this accident.",
#   'Sure.'),
#  ('Can you give me a summary regarding what those injuries are?',
#   'Yeah.  So banged up and bumps and bruises all over.  I had a particularly bad one on my left hand or left wrist area and then the three compression fractures in my back and a concussion.'),
#  ('So generally bumps and bruises?', 'Yeah.'),
#  ('Throughout?', 'Yeah.'),
#  ('An injury to your left wrist?',
#   'Yeah.  I think the ER just referred to it as a contusion but a bruise, contusion, whatever.'),
#  ('A fracture to your thoracic spine, correct?',
#   'Yeah.  There were three vertebrae.'),
#  ('Any injuries did you say to your ribs?',
#   'No, nothing specific to my ribs. Everything is all sort of mixed up in the back, but this muscle here (indicating), I think they call it the lumbar, in my back right side was pretty badly strained.'),
#  ("So let me see if I got this right. You've mentioned to me the fractures to your thoracic spine and the vertebrae, three different locations, right?",
#   'Yeah.'),
#  ('A contusion to your left wrist and some bumps and bruises assorted through your body. Anything else that you believe you injured as a result of this accident?',
#   'The concussion and the lumbar strain.'),
#  ('Do you believe you sustained any mental health injuries as a result of this accident?',
#   'Yes.  It would be difficult to understate the emotional impact that this trolley accident has had on me and my family.'),
#  ('Have you been diagnosed with any mental health conditions as a result of the accident?',
#   "No, not that I'm aware of. Sorry.  The concussion, we're calling it physical or mental, and everything that falls from the concussion and the trauma, are we calling it physical or mental or are you looking for like a specific named disease or something?"),
#  ('I mean I certainly understand that sometimes a concussion can result in additional stress.',
#   'Yeah.'),
#  ('But sometimes -- I want to separate out the post-concussive syndrome and associated manifestations of that from any mental health concerns, to the extent you can.',
#   'Okay.'),
#  ('Okay.  For example, do you believe that you had increased anxiety following this accident as a result of the accident?',
#   'Yes.'),
#  ('Did you have problems with depression following the accident as a result of the accident?',
#   'Yes.'),
#  ('Had anyone diagnosed you with either of those two conditions and advised that it was because of the accident?',
#   'I\'m just getting tripped up on "diagnosed."  Everybody acknowledges that there\'s stress and trauma and anxiety coming from that. But did someone like write it on a certificate and say you have anxiety? Not that I recall.  But certainly yes, that happened to me and I talked about that with my medical providers.'),
#  ('Since October 1, 2016, have you taken any medication that you believe was prescribed to you because of either anxiety or depression?',
#   'No.'),
#  ('Or both?', 'No.'),
#  ('Have you ever sought out since October 1st, 2016 any psychiatrists in order to explore options for medication to address anxiety or depression?',
#   "We saw Dr. Fitzgerald a few times. And I wouldn't say that we went there with the intention of exploring medication. More that we absolutely needed to talk to somebody and we were open to whatever they recommended."),
#  ("Now let's go back and talk for a second.  I'm going to return to the mental health aspect in a little bit.",
#   'Okay.'),
#  ('But before I get too far ahead on that avenue, I do want to talk a little bit about the physical injuries you sustained in the accident.',
#   'Sure.'),
#  ('Immediately after the accident happened, did you have an opportunity to take a look at yourself and observe whether or not you had any obvious injuries?',
#   "Yeah.  I mean sort of like right when I came to I've got -- I'm on my back with my hips and my legs up in the air above me.  And I've got Ceci and Yaron both on top of my thighs and I'm not sure if I can move my legs.  I'm just pretty sure that I'm paralyzed. And I take some time for people to get untangled from one another, so in that process I was evaluating my body. Is that what you mean here?"),
#  ('And did you see any blood, for example, coming from any area of your body?',
#   "No.  I don't think I had any skin breaks as a result of this accident."),
#  ('Did you see any deformities or swelling start to appear on your body at that time?',
#   "Yeah, for sure.  The wrist was really knotted up and the bruises take some time to come in, but my thighs were black and blue for days afterwards. I didn't take my pants down and check or anything."),
#  ('Did you strike your head as a result of the accident?', 'Yes.'),
#  ('What did you hit it on?',
#   "I mean whatever was behind me.  So I don't know if that's the road, the road with that little piece of plexiglass, some aspect of the trolley wall. I'm not 100 percent sure. Whatever was under me."),
#  ('Were you conscious when your head struck whatever it was that it hit?',
#   'No.'),
#  ('How do you know you hit something?',
#   "Well, I wasn't on that side of the trolley and then when I woke up I was."),
#  ('Did you see any physical manifestations of any head injuries at that time?',
#   "I mean it would have been the back of my head so I don't think I could have seen them."),
#  ('What leads you to believe as you sit here today that you struck your head as a result of the accident?',
#   "Sorry.  Didn't I just cover that? So was the last answer not okay? We were on the one side and then I'm on the other side, so it would be impossible for that to happen without me making contact with the other side."),
#  ('Well, like, for example, did you see any knots on your head or any gashes on your head?',
#   'No.'),
#  ('No?', 'No.'),
#  ("And you don't have any personal recollection that you were conscious for striking anything on your head, correct?",
#   'No.'),
#  ('Okay.  Did you have any head pain after the accident happened?',
#   'Yeah.  I had a bad headache, I mean not immediately after.  The adrenaline is just surging.  Right? But yeah, I definitely had a headache later that day and then, you know, progressively worse over the next couple of weeks.'),
#  ("You've said that your left wrist appeared to be knotting up on you at the scene of the accident.  Is that right?",
#   'Yeah.'),
#  ('Was it bleeding at all or --', 'No.'),
#  ('-- deformed in any way other than just what you could appreciate in terms of the swelling?',
#   'The second thing you said.  Just what I could appreciate in terms of the swelling.'),
#  ('At the time the accident happened did you hear any sounds or could you perceive any sounds that construed to you or indicated to you that you had injured yourself?  Cracks?  Crunches?',
#   "Yeah.  So it's difficult for me to back map this to the moment of the accident, but for weeks after I just kept coming back to this crack in my back and still until today.  You just remember a crash.  Right?"),
#  ('But you personally can recall hearing a crack in your back at the time the accident happened?',
#   "I recall thinking about a crack in my back each and every day after the accident.  I don't recall anything about the exact moment of impact."),
#  ("So although you don't recall hearing the crack at the time the accident happened, it's something that you have recalled after the fact?",
#   "Sure.  Yeah.  That's right."),
#  ('How about your low back, was your low back bothering you immediately after the accident?',
#   'Yes.'),
#  ('At some point you extracted yourself from the trolley.  Is that right?',
#   'Yeah.'),
#  ('Did you stand up on your own?',
#   "It's possible that Ceci and I sort of helped each other up.  I might have grabbed on whatever was around.  Yaron was on top of me, so he may have helped me up. But, generally speaking, we made our way together to the exit.  It wasn't like I was on a stretcher or in a wheelchair or something like that."),
#  ('And you walked out of a location that you believe to be an exit for the trolley?',
#   "Well, I seem to remember like some sort of additional maneuvering required. It wasn't like you're stepping off a bus, for example. I remember Ken and Darrion were on the outside and offering hands and I feel like there was a step over or something, maybe it was a back window.  I'm sure looking at a picture you would know what exactly we went through. That's what I recall."),
#  ('Where did you go from there',
#   "We really just sort of milled about on the highway for -- I don't know -- maybe 20, 30 minutes.  It could have been longer. I don't think I looked at a clock."),
#  ('So milling about like wandering, walking around type of thing?',
#   "Yeah.  I mean I don't think I was any further than a hundred feet from the trolley at any point until I was on the shuttle, the bus thing."),
#  ("At any point did any EMT's come up to you and ask whether you needed any medical attention?",
#   "Yeah.  Pretty shortly thereafter the first EMT's on the scene were doing this like initial triage thing.  They were getting everybody a wristband.  It was green, yellow or red, like how serious are you. And I think, I think Kat and Lauren and Wendy, Wendy I think is her name, all got either yellow or red and I think almost everybody else got green."),
#  ("Okay.  What's your understanding, if you know, what it means to have a green wristband versus a yellow or a red?",
#   "You know, similar to a traffic light.  Right?  There's opposite ends and something in the middle. I would guess red is call the helicopter, but I'm not sure thereafter."),
#  ('Was a helicopter ever called to the scene?', 'Not to my knowledge.'),
#  ('And nobody ever received a red wristband, to your knowledge?',
#   "I don't know.  I couldn't answer one way or the other."),
#  ('You received a green wristband, which on the range of colors would be the least severe.  Is that correct?',
#   'Yeah.  Of those three for sure, yeah.'),
#  ("I think the question that I was asking, I want to kind of circle back to it. Did the EMT's ever come up to you and ask if you needed medical attention at that time?",
#   "I don't recall that question being exactly posed to me, but I do recall the triage so it must have been.  That's the best I could do there."),
#  ('Did you ever ask to go to an emergency room in an ambulance?',
#   "I mean Ceci's finger was pointing this way (indicating) so we needed to go there. Was it for me specifically or for her?  I don't know.  That's where we needed to go."),
#  ('How did you come to get to an emergency room?',
#   'We rode like a bus, like a shuttle sort of thing.  I think it was like a commuter setup, a commuter bus for the area.'),
#  ('What were the circumstances under which you became the passenger on that shuttle?',
#   "So everybody was getting taken to get medical attention and they told us that there was not going to be any room for us at the Beebe place and so there was another vehicle that was going to take us to the Milford Memorial. And they told us that there were no more ambulances because all of the ambulances had been deployed for presumably others in the accident.  I'm not sure.  And so like it was the two of us, I think Sarah and an EMT and the bus driver got put on that shuttle and driven to Milford Memorial."),
#  ('The bus driver was on the shuttle with you?',
#   "No. I'm sorry.  The shuttle driver."),
#  ('Oh, okay.  So Mr. Dowd was not on the bus with you or the shuttle?',
#   'Correct.'),
#  ('So by the time you left in the shuttle the ambulances had already left the scene of the accident?',
#   "I couldn't tell you for sure."),
#  ('During the time frame after the accident but before you left in the shuttle, did anyone come up to you who had advised you that they had observed the accident such as a bystander or kind of a third-party witness to it?',
#   'Not me directly, no.'),
#  ('When you got to Milford Memorial Hospital, what happened next?',
#   "Well, there was like a pretty lengthy I don't know if you would call it triage or what process there.  I just remember like -- this is like a recurring theme as you're trying to get through providers throughout this whole process. It's like nobody wants anything to do with you once they hear it's an accident. So they were trying to get claim numbers from us before they would even see us despite the fact that we had insurance cards.  I remember there was a long discussion at that paperwork desk before we were able to even get back in there. They put one of these (indicating) cuffs on me."),
#  ('A collar, a cervical collar?',
#   "Yeah.  Yeah.  Sorry.  A cervical collar on me. And yeah, I guess they set both Ceci and I up for X-rays.  I would have had my back X-rayed and then brought us back together where I think we saw Sparks, Sparks, Sean Sparks maybe, Mike Sparks.  I can't remember his first name.  Dr. Sparks there saw both of us together. And there was a lot of talk about what they were going to do about Ceci's finger so we can get into that if that would be helpful."),
#  ('Well, tell me, at any point did anyone tell you the results of the X-ray to your back?',
#   'Yeah.  So he said, you know, "I took a look at the X-ray and it looks okay."  And he described what happened to me.  I will never forget this.  He said, "It\'s as if you did an entire NFL preseason in one minute." And I was like "Okay.  But without any of the training, right?"  It was the weirdest thing that anyone has said.  So he didn\'t see the break, the compression fractures on the X-ray.'),
#  ('Oh, okay.  So you left Milford Memorial Hospital unaware that you may have broken certain vertebrae in your thoracic spine?',
#   'Correct.'),
#  ('Okay.  Did anyone do an X-ray of your left wrist?', 'I think so.'),
#  ('And what was the result of that X-ray?',
#   "I don't think there was a fracture."),
#  ('Did anyone do a CT scan of your brain at that time?', 'No.'),
#  ('Did you tell medical providers that you thought you may have lost consciousness as a result of the accident?',
#   "No.  I don't think so.  And we talked about this.  It's probably not correct to refer to a different deposition. I'm not sure."),
#  ('You can go ahead and just testify.',
#   "Yeah.  So similar questions, you know, what's your name, who's the president, that sort of thing, did you lose consciousness, which is reflecting on kind of a crazy question because how would you know if you did?"),
#  ('So those types of questions were also posed to you in addition to your wife?',
#   'Yes.'),
#  ('And were you able to respond to those questions accurately?',
#   'Yeah.  I believe so, yes.'),
#  ('At that time did you have any concerns that you were suffering from any problems with a concussion?',
#   'That was not on my mind at the time.'),
#  ('Were you prescribed medication by any of the doctors at Milford Memorial Hospital?',
#   "Yes.  And I can't remember if it was a painkiller or a muscle relaxer from Dr. Sparks.  And it was filled that evening."),
#  ('Did you go to the CVS?',
#   'Yeah.  I think it was a Rite Aid actually, but yes.'),
#  ('Did you take that medication?', 'I did, yes.'),
#  ('That evening?', 'Yes.'),
#  ('Did you continue to take that medication?', 'I did, yeah.'),
#  ('How did you get back to the Airbnb?',
#   "We took I think it was an Uber, not a Lyft.  But if it's important we can find the records."),
#  ('No.', 'Okay.'),
#  ('And did --',
#   "I'm sorry.  We took an Uber or a Lyft to the Rite Aid where we met up with Rita and Leo and they gave us a ride back to the Airbnb."),
#  ('And once back there, were there other people in the home that had been on the trolley?',
#   'Absolutely.  Yeah.'),
#  ('And do you recall conversations you may have had with them, if any, regarding the accident?',
#   "I would describe the scene in there almost as if it was like an ER or a doctor's office itself.  Right?  Everybody is sitting on the ground with an ice pack or holding their bandage or whatever it is. And it's one of these beach houses, so there's a big ol' family room a giant wrap- around couch or whatever.  So of course we were talking about the accident sitting around there, are you okay, hugging each other, crying, all that stuff."),
#  ("What can you recall or tell me about your wife's mental health condition to the extent you observed it that night?",
#   "I mean that whole night is like a blur.  It's a complete shock.  Nobody's okay.  Everybody has darkest red eyes, just tears everywhere and shocked that we're not dead.  Happy to be together. Ceci had a cast.  She was a mess, yeah."),
#  ('You guys drove home the next day, right?', "That's correct."),
#  ('Were you present for when Stephanie Novak came over to the house?',
#   "Yeah.  I think I saw Steph twice, on Saturday and Sunday. And a point of clarification for you.  So Saturday I think she came over to the house.  Actually, I'm not positive she came Saturday night.  I know some other guests from the wedding came on Saturday night, but I actually don't know if Steph did or not.  I'm not sure. Sunday there was a preplanned brunch for the wedding guests, which we did not go to brunch, but we did stop in and give her a hug and say --"),
#  ('So you went to the brunch location just to see her and say hello?',
#   'Exactly.'),
#  ("You didn't stay for any food?",
#   "Correct.  We actually -- it was too much.  It was, you know, everybody who wasn't in the crash but was in the wedding was there.  And if you've ever been to a post-wedding brunch, it's like a raucous good time and that was not where we were. So I think four of us or maybe six of us went directly across the street and had a sandwich.  We had lunch at a cafe across the street, a sandwich I think is what I said a minute ago.  I remember there was a Ravens game on, so that's why I remember being there around 1:00 o'clock on a Sunday."),
#  ('After having lunch did you leave at that point to go home?',
#   'Yeah.  Because I remember we listened to a little bit of the game in the car, so this whole thing would have been between 1:00 and 4:00.'),
#  ('So you would have gotten back sometime later on Sunday?', "That's right."),
#  ('What was the first medical appointment you had for yourself personally after returning home to D.C.?',
#   "I think we saw Ms. Milward together and I think that was very shortly after. We would have to check the records for the exact date, but it would have been that week. And, again, this was a new place to both of us that was recommended by a friend because of their -- again, a lot of these places in D.C. have rotating doctors so you can get in kind of quick if you don't mind who you're seeing.  So they were able to see us right away and we saw her a few times and always together."),
#  ('At any point did you tell Ms. Milward that you were standing on a trolley at the time that the accident occurred?',
#   "I don't recall specifying sitting, standing, one way or the other."),
#  ('What recommendations, if any, did Ms. Milward have for you in relationship to any injuries that you conveyed to her?',
#   "Yeah.  So my back pain was really bad at the time and I was sort of just really tight and bent over and no strength in my back and the pain like wasn't going away.  I think she put me on Flexeril as a muscle relaxant to try to help with that. And we had seen her a couple of times in the intervening days there maybe. And the pain wasn't going away, the back pain wasn't going away.  And so I ended up getting the X-ray from Milford Memorial because I was able to call them and I guess they mailed me a CD, which I brought into Ms. Milward or put in their portal or something.  And she noticed the comments on the X-ray, which I guess -- this was all new to me at the time.  I didn't know that this is how it works, but the on-call doctor is not necessarily the specialist. So the on-call doctor looks and sees if it's like broken in half or whatever, but then the X-ray specialist reads it later.  And then that specialist comments like yeah, there's probably a fracture here; I recommend a MRI. And so that was her recommendation that I go get that MRI."),
#  ('Okay.  And you eventually did that on October 17th.  Is that right?',
#   "That sounds right, but I'm not 100 percent sure."),
#  ('And at that point were you referred to an orthopedic doctor?', 'Yes.'),
#  ('Dr. Tannous?', 'Yeah.'),
#  ('And were you recommended to him by Ms. Milward or someone else?',
#   "I don't think she gave me his name specifically.  I think that I needed to get the MRI and follow up with an orthopedic specialist is probably what she said.  And that place is right around the corner from our house and appointments were queuing up there so..."),
#  ('So did Dr. Tannous review your MRI and discuss with you the results?',
#   'Yeah.'),
#  ("And what's your understanding of what the MRI showed?",
#   "As I understand it, it's called a compression fracture of my T11, T12 and L1 vertebrae?  Vertebrae, yeah."),
#  ('And what, if any, treatment did he recommend to you at that time for that condition?',
#   "So immediately like right there that day they put this crazy back brace on sort of the shoulders with all these different pull straps to tighten it.  And the relief of getting that thing on was just like instant validation for the pain that I had been feeling for like three weeks. Sorry.  That's not what you asked. He recommended that I wear that brace for a period of I think six to eight weeks and then gradually wean myself off of the brace and then start a course of physical therapy for my back."),
#  ('All right.  Did you have to wear that back brace 24/7?',
#   "No. I didn't have to wear it to sleep or shower, but I wanted to."),
#  ('Okay.  So you received the brace, were instructed to wear it for six to eight weeks?',
#   'Yes.'),
#  ("You didn't necessarily have to wear it to shower or sleep.  Did the back brace help with the pain?",
#   'Absolutely.  So much.'),
#  ('All right.',
#   "I mean I was having trouble getting out of bed.  Like I couldn't lay flat on my back and sit up.  I didn't have the muscle strength to do that or the back sturdiness, whatever it is.  I couldn't do that. I had to lean over, kick my legs off the side of the bed in order just to get myself up and out of bed.  And then as soon as you get that brace on, I could like stand up on my own."),
#  ('Okay.  So your understanding was you would be wearing this brace for the next six to eight weeks and then would have to like undergo physical therapy at that point?',
#   'Yes.'),
#  ('Was there ever any conversation as to the potential need for surgery at all?',
#   "He did not recommend surgery.  I don't remember discussing it.  I don't think we did. And his take was there's not a lot they can do for compression fractures. There's some weird experimental stuff where they are like squirting gel in your vertebrae but, otherwise, you just kind of let your back heal and then you should be good."),
#  ('Okay.  So after six to eight weeks you were able to remove or essentially stop using the back brace, correct?',
#   'Right.'),
#  ('And at that point you then started doing physical therapy.  Is that right?',
#   "That's right."),
#  ('You went to MedStar PT?',
#   "Yeah.  So two things.  One, there was some overlap with me wearing the back brace and me doing physical therapy.  It was sort of a wean yourself off of it kind of situation. And then I would say broadly about MedStar they have done a fantastic job of making you feel like you're at the same place every time and you're definitely not.  There's MedStar Lafayette, which also has -- like the MRI place is separate from the PT place is separate from the doctor's office. So I feel sorry for you guys of having to go through all of these records because there's like different billing offices that all have just the same front desk. So if you're going to ask me clarification on which specific MedStar, it's not even a location, but like which exact one, it's all over the map there for them."),
#  ('The records that I have show that you attended about eight visits of physical therapy for your back.',
#   "Yeah.  That sounds about right. And there was another course of therapy about a year later that hasn't made its way to the records yet, but it is mentioned in one of the write-ups in there."),
#  ('And was that also at MedStar PT?',
#   'Yeah, the same place, the Lafayette Center.'),
#  ('As of January 6, 2017 it was noted that you were pain-free with activity, had met all your goals and are okay for discharge. Do you agree with that?',
#   "I wouldn't say pain-free, no, definitely not.  But if you mean pain-free like with activity?  I don't know if that means with activity. Our goals for physical therapy were to get me to be able to use my back again, or at least that was my understanding of the goals, and I was able to do that. And the exercises that I learned and the routine that I got into there was very helpful for me and it was something that I was able to continue on my own. The time commitment required to continue to take an hour out of the workday to go to physical therapy was not sustainable, but most of the time you go there and it's the same sorts of exercises and they're just sort of standing there with you.  There's not a lot that you can't do at home."),
#  ('Explain to me the progress that you made with your back over a course of months from October through the end of the year, meaning October of 2016 to the end of 2016.',
#   "Yeah.  So I mean first and foremost my primary focus during this entire period was Cecilia and helping her through everything.  So I'm not even sure that I focused on my injuries anywhere near the level I should have, so it's difficult. When I got into PT was like really the first time that I was even thinking about mapping my progress or anything like that.  I was just so happy to have this brace that I didn't have pain so that I could get her to all of the appointments that we had to get her to. And so October is fuzzy for me. Right?  And then November is fuzzy.  And then as we get into -- I don't know when PT starts.  Like mid-November I think is when I start to make a little bit progress because I'm actually paying attention to it and the time has passed enough so that the bones have healed enough and we can start to work on the muscles. It's sort of like you need the brace while you wait for the bones to heal but during that time all of the muscles die or atrophy in the process so then your next thing you need to do is get them back up to shape."),
#  ('When you stopped physical therapy at that point, early January of 2017, did you have periods of time where you did not experience pain in your back anymore?',
#   "Yes.  Yeah.  It's not and it wasn't in January a 24-hour-a-day pain.  It's a pain that is triggered by a specific type of activity, and it's any activity that requires my back to independently support itself.  So the most common are standing at a counter for any reason, cutting vegetables, preparing food, whatever, doing dishes or gardening because your hands are sort of out in front of you with some tools.  Those are the most common and it's every time for those things.  Any time I'm doing any of those things for more than five minutes the pain is there, and that was the case in January 2016 as well. But what changed is I could actually get out of bed.  I could walk around without pain.  That was what we had got through in physical therapy."),
#  ('Okay.  So by January of 2017 you still experienced pain in your back, but it was more situational in nature, typically related to standing for a period of time?',
#   "Yeah.  I wouldn't call it standing though.  It's really using my hands out in front of me, yeah."),
#  ('All right.  You have already mentioned that you believe you sustained a concussion as a result of this accident. Tell me what symptoms you believe you had that were a result of that concussion and how long did they last for.',
#   "So, you know, everything is very much mixed up in the days and weeks after the accident.  And, again, like I said, my number one goal was focus on Ceci at the time. I think I was immediately out of work for maybe two full weeks or a week and a half before I tried to go back.  And that's when it really hit home for me, that first day back at work.  I was on a call and I just had no idea what anybody was talking about and it was like my time to comment because it was like my area and there was no comment coming.  That's when I knew that something was wrong. I had been having headaches. That could have been.  I don't know.  That could have been.  But I know now later that that was the concussion.  I had headaches. I had fatigue.  But it wasn't until I got back to work that day when I realized there was like something going wrong in my brain."),
#  ('So headaches, fatigue and some sort of cognitive deficit?', 'Yes.'),
#  ('Okay.  Tell me about your headaches.  How frequently would you get them back then in October-November 2016?',
#   "Daily.  Certainly in October.  And I got -- that went away much faster than it did for Cecilia, so I'm grateful for that but sorry for her.  But certainly daily in the weeks right after the accident and then less frequently thereafter and I would say that headaches were not really a thing certainly in January."),
#  ('Of 2017?', 'Correct.'),
#  ('How about the fatigue, for how long did you experience fatigue that you related to the concussion?',
#   'Certainly all of October and most of November, yeah.'),
#  ("The cognitive deficit that you've described, how long did you experience that symptom?",
#   "For the rest of that year, yeah.  I mean it's not like it immediately turned off on December 31st or something, but those three months were bad."),
#  ('But by 2017 you had noticed a significant improvement?', "That's right."),
#  ('Do you still have any problems with cognitive deficit that you believe was related to this accident?',
#   "I don't think so."),
#  ('You told me that you returned to physical therapy for your back at some point more recently than January of 2017?',
#   'Yeah.'),
#  ('Tell me again.  When was that?', 'I believe it was the summer of 2018.'),
#  ('And why did you go back?',
#   "For those pains that I've described.  I think you called them situationally."),
#  ('Situational back pain?', 'Situational back pain.  There it is.'),
#  ('And how long did you go to physical therapy at that time?',
#   "It was another like ten or twelve session course.  You know, they dole them out in chunks.  That's how the insurance works.  They're sort of driving the show there, not the practitioners."),
#  ('Okay.  Your left wrist complaints, did those resolve fairly shortly after the accident?',
#   'Yeah.'),
#  ('Your lumbar strain, did that resolve pretty soon after the accident?',
#   "I kind of mixed that up with the back thing, so I think that's all related. I still get that pull right up my back sometimes."),
#  ('Okay.  You attended some therapy sessions with your wife at Therapy Group of D.C., right?',
#   "Is that Dr. Fitzgerald?  I believe it is.  But if that's the one, then that's the one.  That's the only therapy we went to together so maybe that makes it easy."),
#  ('Okay.  Well, then that does.', 'Yeah.'),
#  ('That would be in October of 2016?', "That's right."),
#  ('Were you two there in order to address any type of problems that you were having as a couple following the accident?',
#   "Like marital type, couple type problems?  Is that what you're asking?"),
#  ('Marital problems that you were having because of any conditions you sustained as a result of the accident.',
#   "The problem wasn't our connection to one another.  It was symptoms that we were both experiencing independently and concurrently as a result of the accident."),
#  ('Tell me, if you would, in your words what type of emotional problems were you having following this accident that were caused by this accident?',
#   'I mean the accident itself was completely traumatic and upended your life in every way.  And when you throw on all of the stress of dealing with all of the medical stuff on top of that, you know, we needed help.  And Ceci\'s finger pointing in the wrong direction was kind of the focus because it\'s right there and it\'s sort of obvious and that\'s what you need to do. And then so we\'re dealing with that and they got to put her under and she\'s got surgery and all that.  And then okay, maybe she\'s like in a cast and maybe I had the back brace and a diagnosis by then.  So it\'s like okay, the physical stuff is maybe under control.  Let\'s like try to go to work or try to do some normal stuff after that.  And it\'s just not anywhere near the realm of possibility. Right? So unable to function like a normal human being when it comes to just any -- I don\'t know -- any task.  I\'m sorry.  I guess I\'m not really answering as to emotions. We had I think tried to go to that -- we went to the Ren Fest.  It was like the wrong thing.  And maybe -- I can\'t remember what the exact trigger was, but there were a couple of things that we had tried to do that were sort of normal life things, going to work being one of them. And then I remember just being in the house and, again, it\'s difficult to understate the impact of this.  But Ceci, she\'s a different person for months, for months after this.  And she just sort of, she had this sort of empty look, empty look in her eyes and she just wasn\'t there and she looked at me and she said, "My brain is not the same," just right out there super honest.  Not like I think this thing might be wrong with me or whatever.  Just like factually "My brain is not the same.  I need to see somebody.  I need to talk to somebody.  It\'s not just my finger. There\'s something else going on here." And that\'s what prompted us to try to get that appointment.  And either from him directly or from Ms. Miller -- I can\'t remember who -- it was also recommended to go see the concussion specialist.  And they\'re really hard to get and that\'s why we don\'t end up seeing them for a couple of weeks after the accident and it\'s just really, really hard to get those appointments. Ceci mentioned an appointment with Jessica Clark and she was able to get that evaluation that fall, but her full-day evaluation wasn\'t until April, but I scheduled it on like October 5th.  I mean it was crazy.  That\'s how backed up those people are.  I don\'t know if it\'s a D.C. thing or if it\'s everywhere or what. So that\'s what prompted us to go there.  We know we needed help.  Like we didn\'t know at the time that it was concussion related, emotional related, just trauma generally.  We needed help because we weren\'t normal.  We weren\'t living our lives normally.  I wasn\'t -- you know, you just don\'t cry every day.  That\'s not normal.'),
#  ('Aside from those three visits with Therapy Group of D.C., did you see any other mental health providers associated with the accident?',
#   "That's not the concussion people. Right?"),
#  ('Right.',
#   "Mental health.  We're breaking that separate. So I would say no, I did not see any mental health professionals related to the accident or otherwise."),
#  ('Have you and your wife ever been to couples therapy?', 'No.'),
#  ('As a result of the accident, have you noticed any kind of fears, irrational fears related to public transportation or moving vehicles at all?',
#   'I might have called them irrational prior to October 1st, 2016, but now I would call them perfectly rational and it has happened every single time since then.'),
#  ("Okay.  So every time you're in a vehicle or a public transportation you feel increased anxiety?",
#   "Yeah.  Absolutely.  It's a little bit better in my own car or on my own bike because there's some semblance of control here, which is a big thing that you don't have in the Jolly Trolley or any of those other types of situations, but it's ever-present any time."),
#  ('Has that fear ever prevented you or restricted you from doing something that you would have otherwise done?',
# ...
#  ('How many trees fit on that backyard for you to have leaves to rake?',
#   'What a good question this is. There are 20 fruit trees in the backyard.'),
#  ('And is that part of your larger garden that you have in your backyard?',
#   'Yes.'),
#  ("And what's the size of your garden, if you know?  Or if you can just describe to me what you grow and the extent of your garden.",
#   'Okay.  There are three raised beds in the backyard.  I can probably math it out real quick.'),
#  ('Are those beds four foot by eight foot?',
#   'Two of them are longer.  Two of them are closer to eight, I would say eight by four.  There are two eight by four beds and one six by four.  Those are approximate.'),
#  ('And although your ability to do yard work was limited in the fall of 2016, were you able to resume your yard work activity and gardening in 2017?',
#   "Yeah.  Well, when we first moved in my dad bought me a push mower, the kind that doesn't have an engine.  Right?  You push it to make it go because it's not a huge backyard. And that was really hard to use.  The next year I ended up buying an electric one because of how difficult it was."),
#  ('Have you been able to use the electric mower since then?',
#   "It's a breeze.  I think anybody could use it, but yes."),
#  ('As far as the gardening, have you been able to do the gardening since 2017?',
#   'We have grown some things in the garden since 2017, yes.'),
#  ('More or less than what you did in the summer of 2016 or about the same?',
#   "I for an unrelated reason have grown less in the garden.  We had a harlequin beetle infestation so we had switch to growing nightshades.  We had to stop all lettuces, all brassicas, anything that these beetles could live in.  And so we switched almost exclusively to peppers. We're getting a little deep here.  Sorry."),
#  ("That's all right.",
#   'So peppers take a lot less work, which has been nice, but the pain is there even when dealing with those.'),
#  ("So the less work in the garden was not intentional.  It was related to the bug infestation, but it's become a blessing because it does require you to have to be in the garden less?",
#   'Gardening is painful.  I do less of it, both, A, because there were beetles and, B, because it hurts to do it.'),
#  ('Are you on either Facebook or Instagram?',
#   "I am on Instagram.  I have a Facebook account, but I haven't posted anything in five years probably."),
#  ('Have you posted anything on Instagram about either the accident or your injuries?',
#   'No.'),
#  ("Have you posted anything on Instagram about the vacations that you've taken since October 1st, 2016?",
#   'Certainly.'),
#  ('And what typically do you post on Instagram about your vacations?',
#   "I'm sorry to say where we are in the day, but it's mostly food pictures."),
#  ("Ms. Cole was asking you about your concussion symptoms and it seemed as though most of them had resolved before the end of the year in 2016. It would be fair to say that they had all resolved before your wife's January 2017 accident?",
#   "100 percent resolved?  No, that wouldn't be fair."),
#  ('What would you say still did not resolve by January 2017?',
#   "I still had headaches, but just it felt so dwarfed in comparison to Ceci's."),
#  ('You mentioned that you had no more than three beers while you were playing disk golf --',
#   "That's right."),
#  ('-- that morning of the acccident?', "That's correct."),
#  ('You said there were about a dozen other people that joined you playing disk golf. Were the other eleven or so people drinking also while playing disk golf?',
#   "It's my recollection that there was a twelve pack, so there were probably a few others drinking, yeah."),
#  ('Do you remember who else was drinking while playing disk golf?',
#   "No.  I couldn't say for sure."),
#  ('Do you believe that anybody had more than three?', 'No.'),
#  ('Was anybody, when you went back to the Airbnb for lunch was anybody drinking during lunch?',
#   "I don't recall one way or the other."),
#  ('Did you have cases of National Bohemian at the Airbnb?',
#   "Probably, but I can't recall for sure."),
#  ('Was there anybody who was in charge of stocking the refrigerator with beer at the Airbnb?',
#   'In charge?  No.'),
#  ('Do you know who did stock it?', 'No.'),
#  ('With respect to the accident itself, do you remember the trolley tipping onto its side?',
#   'Do I remember like however long it took to physically turn onto its side?'),
#  ('Correct.', 'No.'),
#  ('What do you remember -- let me phrase it this way:  What do you remember when you were on the opposite side after it tipped over?',
#   'I remember coming to with my wife and Yaron on top of me.'),
#  ("What's the last thing you remember before then?",
#   "The back end of the van fishtailing.  I remember seeing the tires going the way that tires aren't supposed to go."),
#  ("So you don't specifically have a recollection of it ultimately tipping over onto its side?",
#   "I mean I'm certain it happened but I do not recall flying through the air."),
#  ("I didn't mean to suggest that you did.  I was just trying to figure out to what extent your memory goes to and where it picks up again.",
#   "Right.  So Ceci recalls it bumping something.  I don't have any memory like that.  I don't remember it turning over, flying through the air or anything like that."),
#  ('Were you aware that that specific van and trailer had been used earlier that day to take the wedding party to the wedding?',
#   "I don't recall being aware of that. I've been made aware of that after but I don't think I knew that before."),
#  ('Did you review the police report by chance at any time since the accident to see what the police officer recorded as what his interview with you consisted of?',
#   "I've read the complaint and I think the police report is part of the complaint, but I'm not sure I saw all of the attachments so I'm not sure."),
#  ('Do you recall reading the summary of the interview with you before your deposition today?',
#   "I didn't read it today but I have read it, yes."),
#  ('Have you read it in the last three or four months?', 'Yes.'),
#  ("I just have a few questions about what the police has put down in terms of what you allegedly told to him.  I'm just going to read from the police report.",
#   'Sure.'),
#  ('It says "He" -- and when it says "he," it\'s meaning you -- "He also explained that when the van started swerving back and forth it appeared as if the driver was trying to correct the situation by steering in either direction. However, the back end was still whipping out farther than the front." Do you recall telling the police officer that?',
#   'Sure.  Yes.'),
#  ('Do you recall that happening?',
#   "I recall the back end of the van moving.  At the time I presumed it was due to things that the driver was doing.  I since -- I don't know.  We've talked a lot more about this and learned about fishtailing trailers and the effect that can have on the vehicle in front.  And now I can't say for sure whether or not the driver was taking any actions to make that happen."),
#  ('Were you able to see the connection between the van and the trailer as it was swaying?',
#   'Not that I can recall.'),
#  ('Do you have any knowledge as to whether the trailer became unattached from the van before it tipped over?',
#   "I don't have any knowledge one way or the other."),
#  ('Reading again from the police report, the police officer writes "When asked about the wind, Mr. DiPietro replied the wind was definitely not strong enough to blow the trailer sideways.  However, he was unsure how the wind affected his steering." Do you remember telling the police officer that?',
#   'Sure.  Yes.'),
#  ('Can you elaborate on that statement at all?',
#   "I mean if anybody has been there, there's always a little breeze coming off of the ocean.  But if it was strong enough to affect this trolley, it would have affected it each and every time they drive it.  So I don't think it was a big deal."),
#  ('The final sentence the police writes about the interview with you was "In conclusion, Mr. DiPietro mentioned that when he boarded the trailer it appeared overloaded and the operator should have been able to activate the trailer brakes to try to control some of the swaying back and forth." Did you tell the police officer that?',
#   'I think so, yes.'),
#  ('What made you think that the trailer appeared to be overloaded?',
#   "There are a few guys that were in the accident that have direct experience on farms or otherwise towing trailers and we spent a lot of time talking about what could have gone wrong and I think that's where it came from."),
#  ('So that would have been in the day or two following the accident that you talked to those people?',
#   'Sure.'),
#  ('And who were those people?',
#   'The first two that come to mind are Joe and Mitch, Joe Johnson.'),
#  ('And Mitch Stanton?', 'Yes, and Mitch Stanton.'),
#  ('And what familiarity do you know that Joe Johnson and Mitch Stanton have with respect to farm vehicles?',
#   "Two good stories here.  Joe Johnson used to be the head landscaper for a summer house in St. Mary's.  And I worked for him for a summer, but he did that for multiple summers down there so he's very knowledgeable.  That was a big, big property.  It's Ted Koppel's summer house. So you can imagine there were all manners of trailers and farm equipment and that sort of thing at that property. Mitch, I just know that he grew up on a farm, but I couldn't tell you the extent.  He's got a lot of John Deere clothing."),
#  ('Did either Joe or Mitch mention to you that they believed that the trailer was overloaded, either at the time of entering into the trolley or after the accident?',
#   "Certainly I don't recall anyone saying that as we were boarding or as we were on the accident.  And yes, we've talked about it a whole lot after the accident and now we have learned about the weight limits and everything else so it's all mixed together, but yes."),
#  ('And you told the police officer -- once again, this was only a couple of days after the accident -- that the operator should have been able to activate the trailer brakes. What did you mean by that?',
#   'If it was possible to stop, he should have stopped.'),
#  ('What do you know about this vehicle and whether it had trailer brakes?',
#   "I don't know whether or not it did."),
#  ('Did you know at the time that you spoke to the police officer?',
#   "No.  And Joe had speculated, sorry, that there were trailer brakes because there was some wires.  He recalled seeing some wires.  I didn't see any of that, but he recalled seeing some wires that he thought would have gone to brakes."),
#  ('So, once again, is that information that you were relaying based upon your conversation with Joe?',
#   'Yeah.  Sure, a combination of my own experiences and my conversations with others.'),
#  ("Well, what's your experience with respect to trailer brakes?",
#   "I don't have any experience with trailer brakes."),
#  ('And what do you mean based upon your own experience?',
#   'I mean I was on the trailer. Right?'),
#  ('Right.', 'So if there were brakes he should have been able to stop.'),
#  ("I want to talk just briefly about your wife's injuries. From your perspective, how was your wife before October 2016 when it came to flying?",
#   "Nothing like what she's like after, night and day."),
#  ("I'm asking you what she was like before.",
#   "She was normal on planes.  I think any sane human gets a little nervous when there's turbulence on a plane and certainly she had that.  We'd hold hands on the plane, but she was fine. She was not like I can't get on a plane or I'm terrified the whole time on a plane.  We went on lots of trips together and that was never in the cards."),
#  ("And are you saying that that's how she is now?",
#   "Those increased.  Sorry.  She was fine before.  She's not fine now.  That's what I'm saying.  If you need me to clarify something specific."),
#  ("What are her limitations now on getting on planes and how does she manifest the problems that she has while she's on a plane?",
#   "There is an ever-present dread whenever she's on transit of any kind, not just a plane, but it could be a train, a bus and especially when we're in the back seat of a cab or a Lyft or Uber or someone else is driving."),
#  ("You mentioned while you were sitting in the median after the accident the EMT's were giving green bands, yellow bands and red bands?",
#   'Yes.'),
#  ('Did both you and Ceci get green bands?', 'As far as I can recall, yes.'),
#  ("In terms of Ceci's anxiety prior to the accident for which she was taking medication, can you describe for me what you saw in terms of her anxiety prior to October 1st, 2016?",
#   "Yeah.  I mean the biggest symptom, the biggest manifestation of Ceci's anxiety is her sleep problems, like to a factor of 10 over any other symptoms that there might be. Ceci -- sorry, honey -- she's an overachiever and she's a rule follower, like won't even go to the order, to the pickup spot at a counter to order.  So she needs job and school and life to be going right and feels pressure to make sure that that's happening I think is fair to say. But her problems sleeping were so severe that she had to, just had to have that medicine.  I would sneak into her pill bottle after she got it refilled and take a couple and stick them in a Baggie in my sock drawer so that when we went on trips, even just to her parents for the weekend, I would bring a few with me in case she forgot because she would just not sleep and the whole weekend would be ruined. So that's where it mostly -- I mean she just couldn't sleep.  It started around the time that she had said earlier, which started during her grad school.  I forget the year.  And she just couldn't sleep without assistance."),
#  ('Do you remember the counseling that she had with Christine Marr?',
#   "I mean I didn't go.  I remember that she did go, but I wasn't there."),
#  ('What do you remember her telling you about that or did she not discuss it with you?',
#   "I don't think we got into too much detail about it.  She's just trying to get the sleeping figured out."),
#  ('In terms of your own ADD or ADHD that was diagnosed around 2009-2010, what problems, if at all, did that cause you from doing activities?',
#   "Sure.  It was really about attention span, just having the shortest attention span, like easily distracted, scattered when it comes to planning, to do lists, ordering of tasks,. And then -- and I think that had always been ever-present.  I never was great at homework or any of that stuff in school.  And I eventually talked to the doctor about it and Dr. Macedo happened to be at that practice where I went whenever I got like the flu or something and they did the test there.  They got this test where you look at the screen and something comes up and you're supposed to press it when you see it and I was like in the 10 percentile or something."),
#  ('And did it affect your decision- making?',
#   "No.  I wouldn't say I was making bad decisions because of this."),
#  ("I'm not saying you were making bad decisions but your inability to make decisions.",
#   "There's some nuance there.  It's like the inability to pay attention and make the right to do list which affects decisions, but it's not like I'm making a decision that I would not have made. Does that make sense."),
#  ('And by taking Adderall, did that assist with your decision-making process?',
#   "Yeah.  Yeah.  That one's really hard for me.  I think it was really about attention and planning and structure, which decision-making is kind of wrapped up in."),
#  ('Do you continue to take the Adderall?', 'I do.'),
#  ('And has your dosage changed at all since the October 1st, 2016 accident?',
#   "No. I stopped taking it for like a month right after the accident at Dr. Delasobera's recommendation but then eventually got back on it."),
#  ('Why did he recommend you stop taking it for a month?', "That's a she."),
#  ("I'm sorry.",
#   "And she didn't want anything else mixing around with my brain while it was trying to heal.")]
